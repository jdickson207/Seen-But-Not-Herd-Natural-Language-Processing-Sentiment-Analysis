# %%
### I first imported the required libraries.
import json
import demoji
from csv import writer
from apiclient.discovery import build

### Next, I configured the function parameters for the required variables to pass to the service.
def get_comments(part='snippet', 
                 maxResults=100, 
                 textFormat='plainText',
                 order='time',
                 videoId='lbudA1tvsKM',
                 csv_filename="Tom_Pemberton_channel"):

    ### I now need to make some empty lists to store the information that I want: comment, commentID, and replyCount.
    comments, commentsId, repliesCount = [], [], []
       
    ### I then built the service for calling the YouTube API.
    def build_service(filename):
        key= 'AIzaSyBNKAPHQDx3nvGzE7RgIDOoKLs-Vr5YIDw'
        YOUTUBE_API_SERVICE_NAME = "youtube"
        YOUTUBE_API_VERSION = "v3"
        return build(YOUTUBE_API_SERVICE_NAME,
                 YOUTUBE_API_VERSION,
                 developerKey=key)
    ### I chose the first video and called the service.
    service = build_service('api_key.txt') 
    response_tp = service.commentThreads().list(
        part='snippet',
        maxResults=100,
        textFormat='plainText',
        order='time',
        videoId='lbudA1tvsKM'
    ).execute()
    
    ### I have noticed that there are more comments than my available maximum of 100, 
    ### so I need to make a for loop to ensure I use all of the available comments.
      
    while response_tp: 
                 
        for item in response_tp['items']:
            ### This indexes the items for the three data features that I want.
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            comment_id = item['snippet']['topLevelComment']['id']
            reply_count = item['snippet']['totalReplyCount']
            
            ### This must also append to the lists.
            comments.append(comment)
            commentsId.append(comment_id)
            repliesCount.append(reply_count)
            
            print(comment)
            print(comment_id)
            print(reply_count)
            
        
        try:
        ### I must also check for nextPageToken and set the response equal to the JSON response if it does exist.
            if 'nextPageToken' in response_tp:
                response_tp = service.commentThreads().list(
                    part=part,
                    maxResults=maxResults,
                    textFormat=textFormat,
                    order=order,
                    videoId=videoId,
                    pageToken=response_tp['nextPageToken']
            ).execute()
            else:
                break
        except: break   

    ### Finally, I want to return the data that I am interested in.
    return {
        'Comments': comments,
        'Comment ID': commentsId,
        'Reply Count' : repliesCount
    }

# %%
response= get_comments()
# Out:
# So what happened to Neptune 😳 is he now a prime steak? 😩
# UgyiMH-tg7a0X6FYpUR4AaABAg
# 0
# When do we get to the new baby calf's. Also the calf barn
# UgxiWvm_KgRnoDG24F54AaABAg
# 0
# Loved your ‘quick math’ comment. Told my boys SEE that’s why you need to pass your Math classes!! 😂👍
# UgxDYy9Dev_7FbdYYid4AaABAg
# 0
# "We're only making plans for Nigel ..."
# UgycPyVg_B2OWH-yiSR4AaABAg
# 0
# Hello from Yorkton, Saskatchewan, Canada. Thanks for sharing your great video’s please keep them coming.
# UgweDRd-OOMEOQoMzRV4AaABAg
# 0
# Hi Tom hope you are OK 😊
# UgxZgTIXkN3CFkVu5tl4AaABAg
# 0
# Why is it always wet
# UgwVXFJ3ETF7PKgofgx4AaABAg
# 0
# Здраствуйте изРоссии. Как приятно смотреть, как у вас всё классно сделано, не так как у нас.
# UgwT0ZPKMP1GQ6TMfJ94AaABAg
# 0
# We want to see it
# UgyqyDITUwufwUT49oJ4AaABAg
# 0
# Hello sir . Do you sell fattening calves?
# Ugw140Thdv7s-RUaDaR4AaABAg
# 0
# My dad's got a farm in Wales
# UgxnEAG6Q9kLW87R6ZF4AaABAg
# 0
# What was all the shitty water running under the gate from the outside feeding group and the young ones, where their feed was on the floor- not very good, plus outside area looks like in desperate need of a scrape, down the muck passageway of the shed? Iv never liked dirty, shitty places or bedded areas for any stock!
# Ugz4ZCopoA2L7KxH43l4AaABAg
# 0
# Yes PDs please. We love cow videos 😁
# Ugxu-ZlKyLkkCVSQ_kR4AaABAg
# 0
# Can't beat a video with cows in it
# UgzCiN_k_3g-WyLX-E14AaABAg
# 0
# As the song goes we're making plans for Nigel 🎶🎶🎶
# UgyQptMs_ZP1KrFIc4R4AaABAg
# 0
# What did u do with neptune? Nacker man being shot on farm? Or did he go for big macs
# UgzT1Omk61qoCK_8YGB4AaABAg
# 0
# Filthy.... it doesnt matter how much money he says they are investing to improve the cows comfort when they fail to see a problem with their overall cleanliness. lazy farmers, i feel really bad for the cows
# UgxvDfmD2hGaArwFVod4AaABAg
# 0
# do you fertile test bulls?
# UgzjyOmP2xMjb1ClRvR4AaABAg
# 0
# Glad to see I’m not the only one that “expertly” opens gates without getting off the tractor when I can. 😂😜
# UgwQ97alYt6OBGCNJA94AaABAg
# 0
# Hi Tom. Helping you make your subscriber goal, hopefully.
# Ugwn0DZW9vptiMbeDkR4AaABAg
# 0
# Tom...when is your BBC stuff being aired?  Do you know?   And as an avid watcher of your videos when are you revealing your Top Secret information with your subscribers?????
# Ugz7Tra6HkkWrsIAbJt4AaABAg
# 1
# Tom..Are we getting an update on the new build shed anytime soon?  is it finished have you got cattle inside yet enjoying the new comfortable surroundings?
# UgxW0AYGYBDqdObQ2Dp4AaABAg
# 1
# Your enthusiasm always cheers me up! Really tough these days on mental health being a farmer. Keep up the good work. 👍
# UgxLkiR-9-yDR6IUNdR4AaABAg
# 0
# Yes diffently we want to know.
# Ugwhsh-2JJtTrokF4Ed4AaABAg
# 0
# Looks like the hurlimann is fixed and shutting off with the key now. Good to see.
# Ugw7BkdhGvv5RhwMXWh4AaABAg
# 0
# its not the water, its the reflection off the water
# Ugy_ZKQtOfwDvOm0ant4AaABAg
# 0
# Great videos
# Ugx8bI66Jp9LrGSoPhR4AaABAg
# 0
# yes wanna see pds x
# UgzKLoxykIzoW4TO39F4AaABAg
# 0
# TOM QUESTION: Do you give the cows a treat ala an apple, Other veg, Polo Mint?
# UgwN8GTgNInoodYhhwJ4AaABAg
# 0
# You're getting very cheeky Tom I don't know where the others have noticed it that you've now put your ball where you put your milk in towels the other day when you sorted the mount you are getting cheeky and thinking we don't remember I really do enjoy your film episodes and I think this shed is further along than you're telling us wonderful kiss
# UgzBzYVO2dim548VIXx4AaABAg
# 1
# Do yous finish all your bulls
# Ugw6RrLWSOWrPCfRMXh4AaABAg
# 0
# 11:01 say hello 🐮
# UgwDI3AL-GiCz2y6DjV4AaABAg
# 0
# it's me or your ladys ear you seriously and are happy to be on the video ? 🐮👍
# Ugx9tFicIs2gRtoR4hJ4AaABAg
# 0
# Hi Tom! I Love your videos and your passion for cows and farming, gresta work!
# I would like to Ask, what is the app that you are using for your herd?
#
# Sorry for my bad english, greatings from Slovenia!✌️
# UgxqUk_iLmVlBC1fXyZ4AaABAg
# 0
# I love these videos. The bulls here always remind my wife and me of our own Black bull (we are in a cuckold relationship and my wife has several black bulls)
# Ugz5EqJUnc2cM_OwxYt4AaABAg
# 0
# Nigel was the better choice,  anything named Boris is utterly useless right now.
# UgyMFX66CpiiuF7-qjB4AaABAg
# 0
# Nigel looks tired.
# UgzePP-5xq8o2zttSwZ4AaABAg
# 0
# Great videos Tom keep up the good work. Any advice someone who is starting an ag based channel. I'm 29 and coming from trucking and into farming, I want to try and document how to get into the industry to hopefully get more young blood in. Any help would be greatly appreciated.
# UgyI7Jbl5YlQ4-rzcUh4AaABAg
# 0
# Hi Tom just wondering when the next shed video is
# Ugwn-g6l6CA_8qvFDMZ4AaABAg
# 0
# Hi Tom,I’ve just had a great idea that I would love you to do it’s a day in the life but 100 years ago . Keep creAting great content everyone loves you 👍
# Ugw-G-o3MAEY9YfImnB4AaABAg
# 0
# Can you shave and Pd cows in a video pls 👍🙏
# Ugz_1fBrbnMDYT11k3N4AaABAg
# 0
# be great to see when you PD the group , see how the boy has done
# UgzqL_pZlBtrHlrMrD94AaABAg
# 0
# Seems like it would be very advantages if you graded your worst field for flooding giving it a 5% graded slope from each side to the middle with a 10% grade toward the drainage ditch and reseed for new grass in the Spring.  Gravity would drain the water to the middle and follow the 10% grade down to the drainage ditch.   Just a thought.  🇺🇸🇺🇸🇺🇸
# UgxhaR4bKXMQ8zs1lSF4AaABAg
# 0
# Yes
# UgwZLZtFiTa6HVUl09h4AaABAg
# 0
# Good video brother
# UgwGUlzLuXJdwxoZMn14AaABAg
# 0
# Good selection Tom. He should make a good heard bull.🐄🐂🐄🐂
# UgwlKgyiO43gOTcG-u94AaABAg
# 0
# Tom was there a doubt he wouldn't know which end he was supposed to address 🤣🤣
# Ugy3XOdiovcX9IagfzZ4AaABAg
# 0
# Do you AI your older stock?
# UgyYJcDgBp76Oz48z9h4AaABAg
# 0
# He jumping on stuff?   Lolol
# UgxtouFTNU0XKThp2-B4AaABAg
# 0
# Go Nigel 🐮🤪
# UgyX1BsKGL3lc3TQ8354AaABAg
# 0
# Floodwater - Tom I hope your making use of the portable water pump I sent you.  Good to hear that Nigel  is settling in and getting down to business. 🐮🐮🐮
# UgzQM3RT0oXiftbmWgV4AaABAg
# 1
# Sad about your new “ponds” but happy about nigel! So glad hes up to the job for you guys. Adorable teddy picture at the end too! God bless and take care!!! 🙏🏻🙏🏻🙏🏻🐄🐄🐄🐄🐄🦆🦆
# UgwbycfAOcKnPTWaYV54AaABAg
# 0
# You need a good Australian Blue Heeler to bring in that single beef stock. Would be through the gate in 5 minutes
# UgySZcjiHHkymoXjvJ54AaABAg
# 0
# Hi Tom, Nigel certainly looks like a bull with a really good temperament which must help when you’re getting him do do his work! Although he might be a bit small I’d rather have the resultant calves with a good temperament which makes the herd much more easy to manage making feeding etc easier. Let’s keep our fingers crossed that he’s done his job🤞😊
# UgxHHclhEnJ2MMLCbLV4AaABAg
# 0
# I'd like to ask to you tom
# What happens if the angus cross calf was heifer
# Is she  going to beef stock or milking herd
# Thanks👍
# Ugz4mBi0z5fY7jBnoEB4AaABAg
# 0
# Name of the song please? Thanks
# UgwiNMDFAcJK6We3pr14AaABAg
# 0
# What do you used to worm the cattle and where can you get the gun you used
# UgxVg2NwM1e4zLI_Orp4AaABAg
# 0
# Yes let’s see your preg check the heifers to see if he’s breeding them
# UgwsupFsT0GD4M-xrWp4AaABAg
# 0
# Hi Tom called in to the farm shop today for some goodies have to say the back bacon and square sausage was amazing very tasty 👍
# Ugwkys5SfuPS3gAKA9d4AaABAg
# 0
# Old Bull is standing on a hill looking down at all the cows.
# Young bull comes up and say’s “see ya later old man I’m going run down there and Fxxx me one of them cows”.
# Old Bull laughs and says “you go on ahead youngster and run down there…… I’m gonna walk down there and Fxxx them all!”
# UgywQgpWHsC-Yrt7DK14AaABAg
# 0
# Hello tom, i was just wondering how many milking cows is it you have . Keep up the good work
# UgyxVJBm33p96TMC8nF4AaABAg
# 0
# Every time Tom says, " ....and sometimes.......!", I always pause with anticipation, as if I don't already know what he'll say...  (or do I?)
# UgyvxDWa5Go_5hzqS-R4AaABAg
# 0
# Way to much talking making little sense as usual.
# UgzgWC8ziwhmp2UVoYR4AaABAg
# 0
# Great video mate ❤️👍🏻
# Ugxk2ie9yoWzy7nFhsh4AaABAg
# 0
# Where has Heidi gone?
# Ugx5vhSBAle2XMrARZp4AaABAg
# 0
# The question on  my mind also a lot of your followers I would imagine.  Where did Heidi go ?.Why do you always avoid giving your followers an explanation.  You have said if it wasn't for your followers you wouldn't be were you our yourself today. Will you kindly answer the question..
# UgxxApDPXmab6t6VZ4Z4AaABAg
# 0
# Give him a sweet treat maybe he will be eating out of your hand we hadca bull that did
# Ugx-ADOFlDeibra3gKF4AaABAg
# 0
# Dang... Seems like the vid was only 5 minutes long. GUESS I'M A TP addict !!!! Already looking for the next video.....Keep them coming Tom.
# Ugw60RcAyDKFs_KkPLp4AaABAg
# 0
# Great video Tom 😎👍🏼
# UgxJo1eUa61TiFlYJyt4AaABAg
# 0
# OMG the font on the thumbnail image 🧐🤣
# Ugyjs1-ejMBc4yeTXyp4AaABAg
# 0
# 👍
# Ugw8PzDIPlgLEHE7Nrt4AaABAg
# 0
# For a minute there i thought your helper was the young farmer from clarksons farm 😯
# Ugxc58W5sQ8v61x7O3N4AaABAg
# 0
# Yes be nice to see cattle been PD always interesting to see how many a new bull has covered
# UgxxetDKBs9PvJPD3Zp4AaABAg
# 0
# When are you going to upload the plowing match in Ireland
# Ugx7_ilHjbC2DQrlwpV4AaABAg
# 0
# You may want to bring Nigel some treats, so that he learns that good things always happen when you come around. Edit: when the camera comes around. Big up maths!
# UgzLJj4LHnBvMtvtyjx4AaABAg
# 0
# Always enjoy your videos Tom.
# Ugxh4lT9nD94etwQkeJ4AaABAg
# 0
# Thank you for this video about Nigel and the ladies! As much as I’ve loved watching everything about the new barn build, I’ve definitely missed seeing the cows!! ❤️❤️
# Ugwu-BVOAMDq6ELtF_h4AaABAg
# 0
# Jesus no they should only be going in calf at 24 months not calling
# UgyWYO2S7f86m6VAGjR4AaABAg
# 0
# Double top, dip your bread in, the heifers are going to get bullies star prize.🤣🤣
# UgxCN_qIaEufUXsZdB14AaABAg
# 0
# Yes please, film everything!!
# UgwlWEa1LTuAifyOqkN4AaABAg
# 0
# I know nothing about cows but what kind is the cow that is on your left near the end of the video. It is Carmel in colour with a dark face and white snout. It is so beautiful.
# UgxOPBA9-jELfP84Q-V4AaABAg
# 0
# Hi Tom can you film pd the on yourube please
# Ugyfil6fcIKQfNPPWm94AaABAg
# 0
# You lead a double life ?????????????????/ LOLZ - https://www.youtube.com/watch?v=fU_pilTk624&ab_channel=SmarterEveryDay
# UgxCeum1H8PsbXUHrWh4AaABAg
# 0
# Dude love the channel, love the videos. I don't know squat about cows but cant not watch your videos they are just that good! Hope you and the cows are well :)
# UgwSA7Y_7IcRErPE5Sl4AaABAg
# 2
# Tom, just watching the video of Today's work on the farm, great to see the younger stock bull in action how did the bull fair out IN EBI, temperament rating, fertility, fat, etc, is he from good stock, great to see your Dad involved, he looks younger than you and livelier [only joking], how is the new cow shed coming on, your commentary on the farm life is great, not like most television stations, pre written, yours is full on with an odd curse, love the truth about it
# UgybailNES3MA_E02oN4AaABAg
# 0
# Great video Tom keep up the great work 👏👏👍👍
# UgyhgkAoE_EAvd9cthR4AaABAg
# 0
# Why do you drive on the land when it is wet.???
# Ugz1TDtcRYhMW_gTMlZ4AaABAg
# 0
# Tom? A Question.... can cows walk down stairs?
#
# Also love how you can't stop talking to the camera and have to cut it because you've so much energy going forward.
# UgzNeYejoEn0FoRFa-Z4AaABAg
# 1
# Start a betting pool for merch on when and if the cows calf in the spring  :)
# UgymDz_G_ACg0vgtwQV4AaABAg
# 0
# Tom I can’t find the bell icon for new episode alerts, where is it? I watch you using an iPad.
# Cheers  Guy
# Ugyr6PwA20CY5WFrcWB4AaABAg
# 0
# Would love to see the pregnancy tests!!! Hope Nigel grows up as big as Neptune was.
# Ugx1YVW4ydfNpV7i6u14AaABAg
# 0
# For a rough calving date Tom on the date she is serviced subtract 3 months and add 1 week, or take 3 and add 1.
# Ugxm1CXWzN_ipcvc0CB4AaABAg
# 0
# Great video great to see nigel again wondered where he was and good luck.
# Ugxu3P7p7TZ5wD499kt4AaABAg
# 0
# Do you have to keep telling us the same thing every time you do a new video
# UgxJJBP6gWczvj9DhVB4AaABAg
# 0
# 💙
# UgwgD0Nrbd89oHZBLqx4AaABAg
# 0
# You have a really cool farm.
# UgzeVvBhdqr96kGEkTp4AaABAg
# 0
# can you put song names in plz
# UgwdBnTGLDaLfTnrm5h4AaABAg
# 0
# I’m like Nige, I liked their tails and back shaved when I was a young un,  tells you all you need to know about how fussy I was as a boy 😂😂😂😂
# UgwbzDoB1hM9YzJWv3B4AaABAg
# 0
# The reg on the cattle trailer is untaxed
# Ugx29IcOdMsQFHPeeft4AaABAg
# 0
# Tom Nigel looks amazing since the last vid of him.  He looks like the Angus bull I had this summer.  He has a strong straight back.  Yes can you do another PV video?
# Cheers Tom! hope your wife and folks are doing wonderful.
# Ugy-J2ogCJB6NsKmWC94AaABAg
# 0
# I'd love to see you pding them for a Sunday video
# UgxenpgHZgKKq2pe6-p4AaABAg
# 0
# The Ginge will tell you the Bull has the best Job on any farm 😂
# UgyOnnBUtKHceAZqsx94AaABAg
# 0
# From Canada. Is there much difference in the way you treat beef cattle vs milking cows, other than he obvious milking and medication care?
# UgwmpS3jfktqnPBr4AZ4AaABAg
# 0
# He's looking Lovely nigel
# Ugziwb9alE3HkLKjkbZ4AaABAg
# 0
# Show us more cow videos!!!
# UgzCDgWXGLl0gcfQ4Gh4AaABAg
# 0
# Nice gate opening system Tom 😂
# UgwdZvvw6JYpbbbNfNJ4AaABAg
# 1
# Let’s us know if they are pregnant
# Ugwo_EzVlmZ51CD6a4F4AaABAg
# 0
# Funny how he speaks normal to the camera then transforms to full on British deep accent when to his dad🤣🤣
# UgzDMgA86U5G5vz0tzB4AaABAg
# 0
# Tom the pimp lol 😂
# UgySlNPrjeEcpJMiGRN4AaABAg
# 0
# Isn't that what the front end of the tractor is for, nudging gates open?
# UgyoNhlHIBXZptlp97J4AaABAg
# 0
# Another great video Tom as always Nigel look good 👍 keep them coming stay safe 👩‍🌾👍👌
# Ugw56o115V_jg61fBcB4AaABAg
# 0
# This video was very dark,hard to see.
# UgyXcYLUO_0O0JPvLf94AaABAg
# 0
# I don’t know if he can do the job but i certainly do know he’s a handsome chap!
# Loved the video
# UgzaBxQ4F_xSF8hEbAN4AaABAg
# 0
# Big Nige, getting it on! Great to see
# UgyHjQZmYwzVMCdavz94AaABAg
# 0
# Top video ,great to see ,nice new bull Nigel ,hope he does well ,🚜👍
# UgwKcxegqdZxNgNTEZF4AaABAg
# 0
# I'm in West Yorkshire and it seems to be a very dry November, even after some rain the ground is dry again in no time there is less mud than they was in the summer when we had the wet spell 🤔
# Ugwvxub1G95DOwikXox4AaABAg
# 0
# 🇿🇦♥️
# UgxNO2jh0R4R1WhnREt4AaABAg
# 0
# Pimp life.
# Ugyq46izvi0uOHJfsKd4AaABAg
# 0
# We need to see the new shed for an update Tom, I bet it’s full of cows now 😂😂😂
# UgwH6T0m87dyZFiq9194AaABAg
# 0
# Yes I want to see that
# UgxqEF5CwUOSdruGovd4AaABAg
# 0
# Luke looks a bit  like kaleb Cooper from the back at times 🤣
# Ugy2dNJVxDtYRhskjux4AaABAg
# 1
# Of COURSE, we want to see the PD's! Who enjoys these vids who doesn't want to see the cows getting PD'd? Nigel may be a bit young but he is put together well and the girls obviously like him! Angus cutie parade :D I like the way you are taking your time with the younger and leaner cows. Learning lots!
# UgwSg5tcl0oj-GISwgJ4AaABAg
# 3
# Show us more cow content! Love it
# UgwrM5aSqGCqrHerioh4AaABAg
# 0
# Trying to do some investigation to see if i can crack the top secrets thats upcoming .maybe you already have a  truck , googled the number plate on the stock trailer , is that hilux yours tom ?😁 ,… if so its has no tax on it 🤷🏽‍♂️😂😂
# Ugzz3t-EOf15wrHZqRp4AaABAg
# 0
# Great to see Nigel working well. Now he's doing well  it's about time you did the same, or there will be no Junior Pembertons to follow on farming. LOL
# UgzAeIWZ6axaKDVJnv94AaABAg
# 2
# Nice bull
# UgylO4nJZ33Qy9pGjj14AaABAg
# 0
# Who dislikes these videos? I don’t get it, if you don’t like it or are indifferent then just move on to something more of your taste.
# UgzBgCOD9lhALCUpoed4AaABAg
# 0
# Can't wait for . MASSIVE ___KG BULL DESTROYS CRUSH. again
# UgxRxLf32Kmr_Zzz2Y54AaABAg
# 0
# Why don't you start your video with "Hi guys" or "How is everyone"???
# UgwPeM-xgGWb-8ry3QV4AaABAg
# 0
# "English so-so," lol. I watch several UK youtubers, many out of Leeds/Sheffield, one in Manchester, one Scouser, and a few Londoners, and you're by far the easiest to understand (to an American, at least)
# UgyZXMNJjzxniM01T6p4AaABAg
# 2
# What speed does the tractor do
# UgxqeBjCEda-gObOibB4AaABAg
# 0
# Has big Nigel got the Balls for the job HARR-HARR only time will tell
# UgzoddvlnCuxdAsGOYh4AaABAg
# 0
# @Tompemberton great vid mate.
# Just wondering as it's been sometime now since the new foot bath was installed. Have you noticed improvements with the cows hoofs from previous years?
# UgyToeiV0VNUMcHj7cJ4AaABAg
# 2
# Good video Tom looks like you had some rain a bit of water around. Nigel is quite small not like Neptune but size does not matter  he will get the job done !! See you in the next one  USA fan!
# UgzWl32viZOaxlXM0lx4AaABAg
# 0
# Look at the topline on big Nigel! <3
# UgyqwA0bFLdR5fiyWal4AaABAg
# 0
# Awesome video tom! Watched a tiktok of a cow playing fetch with a tyre today and thought of you 🤣. You are just about mad enough to put all the tyres round the farm to use by playing fetch with the cows 🤣. And i cant at all hear Nigels name without singing kev wilsons NIGEEEEEELLLL.....THE &*!@NG LEGEND! 🤣
# UgxIGPOJLQAcF0ECSyZ4AaABAg
# 0
# Lol, HE  reminds me of my yourger self.
# We often went to town when the pubs closed for the same reason ..
# Ugw_r7xuDlBpsMlo0Ft4AaABAg
# 0
# I need Nigel as my wingman 🤔🍻
# UgzPGYOhEwXgG-LoGf94AaABAg
# 0
# Young bull runs for one, old bull walks for them all.
# Ugxc8F8n_KDFNrldtsp4AaABAg
# 0
# 🥰
# Ugy1lc-0VWKWtJDQcqB4AaABAg
# 0
# Your heifers are looking good with super nigel
# UgyTSzZS4nu8Ff5PZwx4AaABAg
# 0
# Will he get bigger?
# Ugz2MCQmun9Q2sZrFt94AaABAg
# 0
# Keep up the good work Thomas
# UgzNJlj_TzHU_7g02eF4AaABAg
# 0
# Good to see Nigel doing his job, interested to see how the calves come out like from him! Sort of like how I've gone from an old to a young bull and crossing everything to hope they carry on the good work the previous bulls did.
# UgzlLdx30Xi6khlTvUF4AaABAg
# 0
# Why don't you rope the one cow in the field and drag him in with a tractor or an atv?
# Ugwq6eQq7qOHkxzbrTF4AaABAg
# 0
# He may not be tall and he may be a bit small, but you can always count on Nige to oblige.
# UgxGC-hGwD1ju7Y75lx4AaABAg
# 0
# He will come right Tom, because if I remember correctly, he's from the same blood line as Neptune the King! 👑👍😀
# Ugwz0u5NTMb41TuLlfV4AaABAg
# 0
# So glad to see that Nigel is doing well! Hopefully the ladies all love him, and you'll have a big batch of little Nigels in the spring. Sounds like Neptune really was the character he seemed while he was on camera. Just give Nigel time, he'll get there!
#
#
# Edit: And yes to any videos with the cows in, I love watching them!
# Ugy72sEzQwQ78UJKpaB4AaABAg
# 2
# Do you have a finish date by which all the  building work will be done
# UgyO70HrIv3IdpXPJed4AaABAg
# 0
# Neptune RIP? We all know he's more like RIG (Rest in Gravy 🤣)
# UgxNG_8j3GPJScXPGdB4AaABAg
# 0
# TIME is running OUT , RETURN to your CREATOR
#
#
#
# Dear sir / madam,
#                              My sweet brother/sister in humanity,
#
#                                                                                                  I am inviting you to the inevitable universal truth of our creator of the heavens and the earth i.e; “ there is no god but allah (the true god) , and Muhammad (s.a.w) is the servant and final messenger of allah “.
#
#                                                	REFERENCES FOR SEARCH OF THIS TRUTH
#
#
#        Books of Dr. zakir naik & DR. ved prakash upadhyay available in the online/offline market:-
#
# 1)	Is quran god`s word.
# 2)	Answer to non muslims common questions about islam.
# 3)	Quran and modern science.
# 4)	Islam and Christianity
# 5)	Muhammad (s.a.w.) in the hindu scriptures, etc.
#
# Some important links:-
#
# 1)	Dr. zakir naik youtube videos.
# 2)	Ef dawah youtube videos.
# 3)	Dawahwise youtube videos.
# 4)	Sapience institute website, etc.
#                                                   	Hidayatallah .
# UgwxOwUv2xekcWMpk9x4AaABAg
# 0
# Keep up the good work Tom
# UgxMFTWxNnWfwEgIeQB4AaABAg
# 0
# So glad you are picking little cows for the little bull, I would hate to see him fall off a tall cow, bulls are so unsteady on two feet!!
# UgxPIo9B52rHMzPK0nB4AaABAg
# 0
# So Nigel is going to be busy!! I have been reading and he can “service” up to 20 a day?
# Ugwp3nrjAysvVKIxPrd4AaABAg
# 0
# Just got my merch  great quality just like the videos
# UgzumNdOxy32oGlPumN4AaABAg
# 0
# Everyday's a school day!
# UgxJEj8H0_KJsalKI6l4AaABAg
# 0
# Do we want a video of the cows being PD'd.....🤔
# Is this a rhetorical question?!
# UgxVpID7vsilFd3Zz2R4AaABAg
# 0
# Great video Tom!!  Who was the little girl at the end?  Cute!!
# Ugzx5nJYvBJl1nP36MV4AaABAg
# 0
# Yes please Tom
# UgzZ6MQk5St6yjpp7qJ4AaABAg
# 0
# what im intrest in .. howe the neighbors farm fit in in youre  farm and what ther gool to do ..just wondering!!  Crack on!!
# Ugym33Ikx_0NkTaShRl4AaABAg
# 0
# 😊
# UgzFRKULzRM51wTIgkF4AaABAg
# 0
# Was that Tilly popping in to say Hello? Nige will hopefully grow into Neptune's hooves.
# UgzlUYy3hMPM4pSgeGt4AaABAg
# 0
# You can't really call him Big Nige yet 😂😂
# With practise and exercise over the next year I think he'll certainly become BIG Nige 😆👍
# UgwpyKdRwZ6rdfsQB2B4AaABAg
# 1
# Tom yet again a great video. Let's hope Nigel can follow the great Neptune.
#
# Would love a couple of your t-shirts but you don't do them in my size.  I'm a big build lad of 6XL and if I got yours I'd have to sew two together lol
# Ugxv2diEMfYif85lfm94AaABAg
# 1
# Facts with Tom!  Love it.
# UgzmmzpcMymvB9q1dXx4AaABAg
# 1
# The look on your face while talking about the one that refused to come in...🤣😏
# UgwPppiNm0_xQ3y13_h4AaABAg
# 0
# I hope you ar least got some nice steaks out of Neptune! He would have wanted it that way! He was and will always be a legend!🐃
# UgxQnuKql3FwrF_VPIV4AaABAg
# 0
# could you do a video of cows bein pd
# Ugw455bXnGPvgrF-x7R4AaABAg
# 0
# Another great video tom love you videos  reminds me of when I  was on my grandads farm
# UgzCKsm4q1dbmnkv7mR4AaABAg
# 0
# Hello Tom, want to ask why you choose single cubicles instead duble face to face cubicles in the new shed?  Thanks and keep up the good work whooop whoooop
# UgxP_RnkP8yi4PtKcxl4AaABAg
# 1
# Hows your Live Barn cam coming >? lol
# UgzTUm6B2IySPQk8-9R4AaABAg
# 0
# Predict it won’t be long to be hits 500,000 and receives a little YouTube plaque.
# UgzgNNLWW8R1Zlxa7mx4AaABAg
# 0
# Tom I love u videos and I like Ur cows
# Ugz-CFFGGSeTymgQzbl4AaABAg
# 0
# Great videos keep it up 👍
# UgzD4NbeHLjKpgbaVkt4AaABAg
# 0
# Hello
# Ugz_IRmSFs5CEhpOdtt4AaABAg
# 0
# Congratulations on hitting 402k subscribers.
# UgxQ7RUdn1Y-37jgw8h4AaABAg
# 1

# %%
type(response)
# Out:
# dict

# %%
response.keys()
# Out:
# dict_keys(['Comments', 'Comment ID', 'Reply Count'])

# %%
import pandas as pd

# %%
df= pd.DataFrame.from_dict(response)

# %%
df.to_csv("TP.csv")

# %%
df1= pd.read_csv("TP.csv")

# %%
df1.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0                                           Comments  \
# 0             0  So what happened to Neptune 😳 is he now a prim...
# 1             1  When do we get to the new baby calf's. Also th...
# 2             2  Loved your ‘quick math’ comment. Told my boys ...
# 3             3            "We're only making plans for Nigel ..."
# 4             4  Hello from Yorkton, Saskatchewan, Canada. Than...
# ..          ...                                                ...
# 171         171  Predict it won’t be long to be hits 500,000 an...
# 172         172             Tom I love u videos and I like Ur cows
# 173         173                          Great videos keep it up 👍
# 174         174                                              Hello
# 175         175       Congratulations on hitting 402k subscribers.
#
#                      Comment ID  Reply Count
# 0    UgyiMH-tg7a0X6FYpUR4AaABAg            0
# 1    UgxiWvm_KgRnoDG24F54AaABAg            0
# 2    UgxDYy9Dev_7FbdYYid4AaABAg            0
# 3    UgycPyVg_B2OWH-yiSR4AaABAg            0
# 4    UgweDRd-OOMEOQoMzRV4AaABAg            0
# ..                          ...          ...
# 171  UgzgNNLWW8R1Zlxa7mx4AaABAg            0
# 172  Ugz-CFFGGSeTymgQzbl4AaABAg            0
# 173  UgzD4NbeHLjKpgbaVkt4AaABAg            0
# 174  Ugz_IRmSFs5CEhpOdtt4AaABAg            0
# 175  UgxQ7RUdn1Y-37jgw8h4AaABAg            1
#
# [176 rows x 4 columns]>

# %%
import demoji

# %%
comments= pd.read_csv("TP.csv")

# %%
comments
# Out:
#      Unnamed: 0                                           Comments  \
# 0             0  So what happened to Neptune 😳 is he now a prim...
# 1             1  When do we get to the new baby calf's. Also th...
# 2             2  Loved your ‘quick math’ comment. Told my boys ...
# 3             3            "We're only making plans for Nigel ..."
# 4             4  Hello from Yorkton, Saskatchewan, Canada. Than...
# ..          ...                                                ...
# 171         171  Predict it won’t be long to be hits 500,000 an...
# 172         172             Tom I love u videos and I like Ur cows
# 173         173                          Great videos keep it up 👍
# 174         174                                              Hello
# 175         175       Congratulations on hitting 402k subscribers.
#
#                      Comment ID  Reply Count
# 0    UgyiMH-tg7a0X6FYpUR4AaABAg            0
# 1    UgxiWvm_KgRnoDG24F54AaABAg            0
# 2    UgxDYy9Dev_7FbdYYid4AaABAg            0
# 3    UgycPyVg_B2OWH-yiSR4AaABAg            0
# 4    UgweDRd-OOMEOQoMzRV4AaABAg            0
# ..                          ...          ...
# 171  UgzgNNLWW8R1Zlxa7mx4AaABAg            0
# 172  Ugz-CFFGGSeTymgQzbl4AaABAg            0
# 173  UgzD4NbeHLjKpgbaVkt4AaABAg            0
# 174  Ugz_IRmSFs5CEhpOdtt4AaABAg            0
# 175  UgxQ7RUdn1Y-37jgw8h4AaABAg            1
#
# [176 rows x 4 columns]

# %%
comments['clean_comments']= comments['Comments'].apply(lambda x: demoji.replace(x, ""))

# %%
comments.head()
# Out:
#    Unnamed: 0                                           Comments  \
# 0           0  So what happened to Neptune 😳 is he now a prim...
# 1           1  When do we get to the new baby calf's. Also th...
# 2           2  Loved your ‘quick math’ comment. Told my boys ...
# 3           3            "We're only making plans for Nigel ..."
# 4           4  Hello from Yorkton, Saskatchewan, Canada. Than...
#
#                    Comment ID  Reply Count  \
# 0  UgyiMH-tg7a0X6FYpUR4AaABAg            0
# 1  UgxiWvm_KgRnoDG24F54AaABAg            0
# 2  UgxDYy9Dev_7FbdYYid4AaABAg            0
# 3  UgycPyVg_B2OWH-yiSR4AaABAg            0
# 4  UgweDRd-OOMEOQoMzRV4AaABAg            0
#
#                                       clean_comments
# 0  So what happened to Neptune  is he now a prime...
# 1  When do we get to the new baby calf's. Also th...
# 2  Loved your ‘quick math’ comment. Told my boys ...
# 3            "We're only making plans for Nigel ..."
# 4  Hello from Yorkton, Saskatchewan, Canada. Than...

# %%
comments.to_csv("TP_clean.csv")

# %%
import pandas as pd
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Jilian\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
df1= pd.read_csv("TP_clean.csv")

# %%
df1.head(20)
# Out:
#     Unnamed: 0  Unnamed: 0.1  \
# 0            0             0
# 1            1             1
# 2            2             2
# 3            3             3
# 4            4             4
# 5            5             5
# 6            6             6
# 7            7             7
# 8            8             8
# 9            9             9
# 10          10            10
# 11          11            11
# 12          12            12
# 13          13            13
# 14          14            14
# 15          15            15
# 16          16            16
# 17          17            17
# 18          18            18
# 19          19            19
#
#                                              Comments  \
# 0   So what happened to Neptune 😳 is he now a prim...
# 1   When do we get to the new baby calf's. Also th...
# 2   Loved your ‘quick math’ comment. Told my boys ...
# 3             "We're only making plans for Nigel ..."
# 4   Hello from Yorkton, Saskatchewan, Canada. Than...
# 5                            Hi Tom hope you are OK 😊
# 6                                Why is it always wet
# 7   Здраствуйте изРоссии. Как приятно смотреть, ка...
# 8                                   We want to see it
# 9           Hello sir . Do you sell fattening calves?
# 10                       My dad's got a farm in Wales
# 11  What was all the shitty water running under th...
# 12               Yes PDs please. We love cow videos 😁
# 13                 Can't beat a video with cows in it
# 14  As the song goes we're making plans for Nigel 🎶🎶🎶
# 15  What did u do with neptune? Nacker man being s...
# 16  Filthy.... it doesnt matter how much money he ...
# 17                         do you fertile test bulls?
# 18  Glad to see I’m not the only one that “expertl...
# 19  Hi Tom. Helping you make your subscriber goal,...
#
#                     Comment ID  Reply Count  \
# 0   UgyiMH-tg7a0X6FYpUR4AaABAg            0
# 1   UgxiWvm_KgRnoDG24F54AaABAg            0
# 2   UgxDYy9Dev_7FbdYYid4AaABAg            0
# 3   UgycPyVg_B2OWH-yiSR4AaABAg            0
# 4   UgweDRd-OOMEOQoMzRV4AaABAg            0
# 5   UgxZgTIXkN3CFkVu5tl4AaABAg            0
# 6   UgwVXFJ3ETF7PKgofgx4AaABAg            0
# 7   UgwT0ZPKMP1GQ6TMfJ94AaABAg            0
# 8   UgyqyDITUwufwUT49oJ4AaABAg            0
# 9   Ugw140Thdv7s-RUaDaR4AaABAg            0
# 10  UgxnEAG6Q9kLW87R6ZF4AaABAg            0
# 11  Ugz4ZCopoA2L7KxH43l4AaABAg            0
# 12  Ugxu-ZlKyLkkCVSQ_kR4AaABAg            0
# 13  UgzCiN_k_3g-WyLX-E14AaABAg            0
# 14  UgyQptMs_ZP1KrFIc4R4AaABAg            0
# 15  UgzT1Omk61qoCK_8YGB4AaABAg            0
# 16  UgxvDfmD2hGaArwFVod4AaABAg            0
# 17  UgzjyOmP2xMjb1ClRvR4AaABAg            0
# 18  UgwQ97alYt6OBGCNJA94AaABAg            0
# 19  Ugwn0DZW9vptiMbeDkR4AaABAg            0
#
#                                        clean_comments
# 0   So what happened to Neptune  is he now a prime...
# 1   When do we get to the new baby calf's. Also th...
# 2   Loved your ‘quick math’ comment. Told my boys ...
# 3             "We're only making plans for Nigel ..."
# 4   Hello from Yorkton, Saskatchewan, Canada. Than...
# 5                             Hi Tom hope you are OK
# 6                                Why is it always wet
# 7   Здраствуйте изРоссии. Как приятно смотреть, ка...
# 8                                   We want to see it
# 9           Hello sir . Do you sell fattening calves?
# 10                       My dad's got a farm in Wales
# 11  What was all the shitty water running under th...
# 12                Yes PDs please. We love cow videos
# 13                 Can't beat a video with cows in it
# 14     As the song goes we're making plans for Nigel
# 15  What did u do with neptune? Nacker man being s...
# 16  Filthy.... it doesnt matter how much money he ...
# 17                         do you fertile test bulls?
# 18  Glad to see I’m not the only one that “expertl...
# 19  Hi Tom. Helping you make your subscriber goal,...

# %%
df1.clean_comments.isnull().sum()
# Out:
# 5

# %%
df2= df1.dropna(subset=["clean_comments"])

# %%
df2.clean_comments.isnull().sum()
# Out:
# 0

# %%
sentiment = SentimentIntensityAnalyzer()
sentiment.polarity_scores(df2.clean_comments[0])
df2['TP_sentiment'] = df2.clean_comments.apply(lambda x: sentiment.polarity_scores(x))

# %%
df2['TP_neg_sentiment'] = df2.TP_sentiment.apply(lambda x: x['neg'])
df2['TP_pos_sentiment'] = df2.TP_sentiment.apply(lambda x: x['pos'])
df2['TP_comp_sentiment'] = df2.TP_sentiment.apply(lambda x: x['compound'])

# %%
# most positive 
df2.sort_values(by=['TP_comp_sentiment'], ascending=False)[['clean_comments']].head(10)
# Out:
#                                         clean_comments
# 51   Sad about your new “ponds” but happy about nig...
# 99   Tom Nigel looks amazing since the last vid of ...
# 147  So glad to see that Nigel is doing well! Hopef...
# 121  Of COURSE, we want to see the PD's! Who enjoys...
# 84   Tom, just watching the video of Today's work o...
# 83   Dude love the channel, love the videos. I don'...
# 39   Hi Tom,I’ve just had a great idea that I would...
# 53   Hi Tom, Nigel certainly looks like a bull with...
# 150  TIME is running OUT , RETURN to your CREATOR\r...
# 37   Great videos Tom keep up the good work. Any ad...

# %%
# most negative
df2.sort_values(by=['TP_comp_sentiment'], ascending=True)[['clean_comments']].head(10)
# Out:
#                                         clean_comments
# 16   Filthy.... it doesnt matter how much money he ...
# 127  Can't wait for . MASSIVE ___KG BULL DESTROYS C...
# 11   What was all the shitty water running under th...
# 36                                  Nigel looks tired.
# 46   Tom was there a doubt he wouldn't know which e...
# 56   What do you used to worm the cattle and where ...
# 165  The look on your face while talking about the ...
# 77   Jesus no they should only be going in calf at ...
# 115  I'm in West Yorkshire and it seems to be a ver...
# 126  Who dislikes these videos? I don’t get it, if ...

# %% [markdown]
# ### Exploratory

# %%
# most number of likes
pd.set_option('display.max_colwidth', None)
df2.sort_values(by=['clean_comments'],ascending=False)
# Out:
#      Unnamed: 0  Unnamed: 0.1  \
# 7             7             7
# 27           27            27
# 159         159           159
# 25           25            25
# 32           32            32
# ..          ...           ...
# 75           75            75
# 132         132           132
# 31           31            31
# 3             3             3
# 129         129           129
#
#                                                                                                                                                                                                          Comments  \
# 7                                                                                                                    Здраствуйте изРоссии. Как приятно смотреть, как у вас всё классно сделано, не так как у нас.
# 27                                                                                                                                                                                            yes wanna see pds x
# 159                                                                                   what im intrest in .. howe the neighbors farm fit in in youre  farm and what ther gool to do ..just wondering!!  Crack on!!
# 25                                                                                                                                                            its not the water, its the reflection off the water
# 32                                                                                                                                  it's me or your ladys ear you seriously and are happy to be on the video ? 🐮👍
# ..                                                                                                                                                                                                            ...
# 75                                                                                                                                                                                  Always enjoy your videos Tom.
# 132                        @Tompemberton great vid mate. \nJust wondering as it's been sometime now since the new foot bath was installed. Have you noticed improvements with the cows hoofs from previous years?
# 31                                                                                                                                                                                              11:01 say hello 🐮
# 3                                                                                                                                                                         "We're only making plans for Nigel ..."
# 129  "English so-so," lol. I watch several UK youtubers, many out of Leeds/Sheffield, one in Manchester, one Scouser, and a few Londoners, and you're by far the easiest to understand (to an American, at least)
#
#                      Comment ID  Reply Count  \
# 7    UgwT0ZPKMP1GQ6TMfJ94AaABAg            0
# 27   UgzKLoxykIzoW4TO39F4AaABAg            0
# 159  Ugym33Ikx_0NkTaShRl4AaABAg            0
# 25   Ugy_ZKQtOfwDvOm0ant4AaABAg            0
# 32   Ugx9tFicIs2gRtoR4hJ4AaABAg            0
# ..                          ...          ...
# 75   Ugxh4lT9nD94etwQkeJ4AaABAg            0
# 132  UgyToeiV0VNUMcHj7cJ4AaABAg            2
# 31   UgwDI3AL-GiCz2y6DjV4AaABAg            0
# 3    UgycPyVg_B2OWH-yiSR4AaABAg            0
# 129  UgyZXMNJjzxniM01T6p4AaABAg            2
#
#                                                                                                                                                                                                    clean_comments  \
# 7                                                                                                                    Здраствуйте изРоссии. Как приятно смотреть, как у вас всё классно сделано, не так как у нас.
# 27                                                                                                                                                                                            yes wanna see pds x
# 159                                                                                   what im intrest in .. howe the neighbors farm fit in in youre  farm and what ther gool to do ..just wondering!!  Crack on!!
# 25                                                                                                                                                            its not the water, its the reflection off the water
# 32                                                                                                                                    it's me or your ladys ear you seriously and are happy to be on the video ?
# ..                                                                                                                                                                                                            ...
# 75                                                                                                                                                                                  Always enjoy your videos Tom.
# 132                        @Tompemberton great vid mate. \nJust wondering as it's been sometime now since the new foot bath was installed. Have you noticed improvements with the cows hoofs from previous years?
# 31                                                                                                                                                                                               11:01 say hello
# 3                                                                                                                                                                         "We're only making plans for Nigel ..."
# 129  "English so-so," lol. I watch several UK youtubers, many out of Leeds/Sheffield, one in Manchester, one Scouser, and a few Londoners, and you're by far the easiest to understand (to an American, at least)
#
#                                                        TP_sentiment  \
# 7             {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 27     {'neg': 0.0, 'neu': 0.597, 'pos': 0.403, 'compound': 0.4019}
# 159    {'neg': 0.0, 'neu': 0.862, 'pos': 0.138, 'compound': 0.5673}
# 25            {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 32   {'neg': 0.083, 'neu': 0.735, 'pos': 0.181, 'compound': 0.4588}
# ..                                                              ...
# 75     {'neg': 0.0, 'neu': 0.556, 'pos': 0.444, 'compound': 0.4939}
# 132    {'neg': 0.0, 'neu': 0.808, 'pos': 0.192, 'compound': 0.7506}
# 31            {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 3             {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 129    {'neg': 0.0, 'neu': 0.851, 'pos': 0.149, 'compound': 0.6808}
#
#      TP_neg_sentiment  TP_pos_sentiment  TP_comp_sentiment
# 7               0.000             0.000             0.0000
# 27              0.000             0.403             0.4019
# 159             0.000             0.138             0.5673
# 25              0.000             0.000             0.0000
# 32              0.083             0.181             0.4588
# ..                ...               ...                ...
# 75              0.000             0.444             0.4939
# 132             0.000             0.192             0.7506
# 31              0.000             0.000             0.0000
# 3               0.000             0.000             0.0000
# 129             0.000             0.149             0.6808
#
# [171 rows x 10 columns]

# %% [markdown]
# ### Build the corpus

# %%
# !pip install scattertext
import spacy.cli
spacy.cli.download("en_core_web_lg")
import scattertext as st
# Out:
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'c:\python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: scattertext in c:\python39\lib\site-packages (0.1.5)
# Requirement already satisfied: pandas in c:\python39\lib\site-packages (from scattertext) (1.3.4)
# Requirement already satisfied: numpy in c:\python39\lib\site-packages (from scattertext) (1.21.2)
# Requirement already satisfied: scikit-learn in c:\python39\lib\site-packages (from scattertext) (1.0.2)
# Requirement already satisfied: flashtext in c:\python39\lib\site-packages (from scattertext) (2.7)
# Requirement already satisfied: gensim>=4.0.0 in c:\python39\lib\site-packages (from scattertext) (4.1.2)
# Requirement already satisfied: scipy in c:\python39\lib\site-packages (from scattertext) (1.7.1)
# Requirement already satisfied: statsmodels in c:\python39\lib\site-packages (from scattertext) (0.13.0)
# Requirement already satisfied: mock in c:\python39\lib\site-packages (from scattertext) (4.0.3)
# Requirement already satisfied: six in c:\python39\lib\site-packages (from scattertext) (1.16.0)
# Requirement already satisfied: smart-open>=1.8.1 in c:\python39\lib\site-packages (from gensim>=4.0.0->scattertext) (5.2.1)
# Requirement already satisfied: Cython==0.29.23 in c:\python39\lib\site-packages (from gensim>=4.0.0->scattertext) (0.29.23)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\python39\lib\site-packages (from pandas->scattertext) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\python39\lib\site-packages (from pandas->scattertext) (2021.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python39\lib\site-packages (from scikit-learn->scattertext) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in c:\python39\lib\site-packages (from scikit-learn->scattertext) (1.1.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\python39\lib\site-packages (from statsmodels->scattertext) (0.5.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
nlp = spacy.load('en_core_web_lg')

# %%
df2.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                                                                                    Comments  \
# 0                                                  So what happened to Neptune 😳 is he now a prime steak? 😩
# 1                                                 When do we get to the new baby calf's. Also the calf barn
# 2      Loved your ‘quick math’ comment. Told my boys SEE that’s why you need to pass your Math classes!! 😂👍
# 3                                                                   "We're only making plans for Nigel ..."
# 4  Hello from Yorkton, Saskatchewan, Canada. Thanks for sharing your great video’s please keep them coming.
#
#                    Comment ID  Reply Count  \
# 0  UgyiMH-tg7a0X6FYpUR4AaABAg            0
# 1  UgxiWvm_KgRnoDG24F54AaABAg            0
# 2  UgxDYy9Dev_7FbdYYid4AaABAg            0
# 3  UgycPyVg_B2OWH-yiSR4AaABAg            0
# 4  UgweDRd-OOMEOQoMzRV4AaABAg            0
#
#                                                                                              clean_comments  \
# 0                                                    So what happened to Neptune  is he now a prime steak?
# 1                                                 When do we get to the new baby calf's. Also the calf barn
# 2        Loved your ‘quick math’ comment. Told my boys SEE that’s why you need to pass your Math classes!!
# 3                                                                   "We're only making plans for Nigel ..."
# 4  Hello from Yorkton, Saskatchewan, Canada. Thanks for sharing your great video’s please keep them coming.
#
#                                                    TP_sentiment  \
# 0         {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 1         {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 2  {'neg': 0.0, 'neu': 0.791, 'pos': 0.209, 'compound': 0.6688}
# 3         {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 4  {'neg': 0.0, 'neu': 0.476, 'pos': 0.524, 'compound': 0.9022}
#
#    TP_neg_sentiment  TP_pos_sentiment  TP_comp_sentiment
# 0               0.0             0.000             0.0000
# 1               0.0             0.000             0.0000
# 2               0.0             0.209             0.6688
# 3               0.0             0.000             0.0000
# 4               0.0             0.524             0.9022

# %%
corpus = st.CorpusFromPandas(df2, category_col='TP_comp_sentiment', text_col= 'clean_comments', nlp=nlp).build()

# %% [markdown]
# ### Most defining words of the channel

# %%
print(list(corpus.get_scaled_f_scores_vs_background().index[:30]))
# Out:
# ['nigels', 'fxxx', 'nigeeeeeellll', 'hidayatallah', 'sapience', 'whooop', 'pding', 'pembertons', 'hadca', 'dawahwise', 'clarksons', 'youtubers', 'yourube', 'tiktok', 'yourger', 'nacker', 'grandads', 'whoooop', 'diffently', 'gresta', 'hurlimann', 'nige', 'ginge', 'youtube', 'greatings', 'scouser', 'ipad', 'upadhyay', 'zakir', 'gool']

# %%
import warnings
warnings.filterwarnings("ignore")
