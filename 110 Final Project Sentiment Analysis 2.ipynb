# %%
### I first imported the required libraries.
import json
import demoji
from csv import writer
from apiclient.discovery import build

### Next, I configured the function parameters for the required variables to pass to the service.
def get_comments(part='snippet', 
                 maxResults=100, 
                 textFormat='plainText',
                 order='time',
                 videoId='LyKuUxkDBf8',
                 csv_filename="SaskDutchKid_channel"):

    ### I now need to make some empty lists to store the information that I want: comment, commentID, and replyCount.
    comments, commentsId, repliesCount = [], [], []
       
    ### I then built the service for calling the YouTube API.
    def build_service(filename):
        key= 'AIzaSyBNKAPHQDx3nvGzE7RgIDOoKLs-Vr5YIDw'
        YOUTUBE_API_SERVICE_NAME = "youtube"
        YOUTUBE_API_VERSION = "v3"
        return build(YOUTUBE_API_SERVICE_NAME,
                 YOUTUBE_API_VERSION,
                 developerKey=key)
    ### I chose the first video and called the service.
    service = build_service('api_key.txt') 
    response_tp = service.commentThreads().list(
        part='snippet',
        maxResults=100,
        textFormat='plainText',
        order='time',
        videoId='LyKuUxkDBf8'
    ).execute()
    
    ### I have noticed that there are more comments than my available maximum of 100, 
    ### so I need to make a for loop to ensure I use all of the available comments.
      
    while response_tp: 
                 
        for item in response_tp['items']:
            ### This indexes the items for the three data features that I want.
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            comment_id = item['snippet']['topLevelComment']['id']
            reply_count = item['snippet']['totalReplyCount']
            
            ### This must also append to the lists.
            comments.append(comment)
            commentsId.append(comment_id)
            repliesCount.append(reply_count)
            
            print(comment)
            print(comment_id)
            print(reply_count)
            
        
        try:
        ### I must also check for nextPageToken and set the response equal to the JSON response if it does exist.
            if 'nextPageToken' in response_tp:
                response_tp = service.commentThreads().list(
                    part=part,
                    maxResults=maxResults,
                    textFormat=textFormat,
                    order=order,
                    videoId=videoId,
                    pageToken=response_tp['nextPageToken']
            ).execute()
            else:
                break
        except: break   

    ### Finally, I want to return the data that I am interested in.
    return {
        'Comments': comments,
        'Comment ID': commentsId,
        'Reply Count' : repliesCount
    }

# %%
response= get_comments()
# Out:
# Farming, Fixing & Fabricating channel has some videos of them using skid steers under their barns scooping out the sand/solids and loading up large spreaders.  They have a nice operation and Andy has great videos.
# Ugzw-v1WGpnjr2-Xv2l4AaABAg
# 0
# It’s PVC not PCV
# Ugz2TltI1vOdIWkhAml4AaABAg
# 0
# To clean that pit at the barn you should rent a vacuum tank truck. It sucks the crap right out of there.
# Ugy03norOg4_escUAZl4AaABAg
# 0
# I went in here to comment and noticed Alex Drake's comment, which is I was going to comment on.  I read year after year about guys who die because of methane from sewers.  Please be careful.  Perhaps talk to your local fire department on safety precautions.  Love you guys videos.
# Ugz18yAPJ-GiU9BboA54AaABAg
# 0
# I would just make sure you carry a oxygen monitor when going in the pit. Very easy to get on Amazon. Abandoned mine explorers use them to detect lack of oxygen that could potentially cause you to pass.
# UgwyDGnrYQ3gqH5YIm94AaABAg
# 0
# Jesus guys   so dangerous getting into a slurry tank   a few yrs ago a farmers dog fell into his tank when he leaned over he was overcome with methane gas and then hs adult son did the trying to save his father     all 3 died    it was the gas    they didn't drown   totally true story   it happens here n Ireland every year   farming yards are the most dangerous environments to work in
# UgwZXGdJHSJOMFPS1Bp4AaABAg
# 0
# Do you always use the pump in the same corner?
# Ugxfw8ZLGc77VDVS-V94AaABAg
# 0
# I sure would hate to live down   wind  from your lands..
# UgySuaRKaj67QlYZPD54AaABAg
# 0
# Make it easier on yourselves, pump the water over, fill the pit, and then agitate it up and then pump it out.
# UgwsGo3utD-G0Y_w5J54AaABAg
# 0
# When are you completing the fence/guard rail system around the lagoon?
# UgxWWvBV7Cqa2i8w4-N4AaABAg
# 0
# PVC not PCV
# UgyYnS_xx0uOiu7m7_h4AaABAg
# 0
# Glad to see you're back I love watching your channel also love watching your big sister's channel can you tell me how far away you are from the US border
# Ugz9K-7Qe7YW_UOjN2p4AaABAg
# 0
# Good one, Jan & Dima! Cheers!
# UgzL5Flgc27xGlos0td4AaABAg
# 0
# Not wearing respirator or tied off for safety while in pit?
# UgxWDl5iZcQ0Dpyf8Vx4AaABAg
# 0
# “PCV”, totally not PVC
# UgzwI3gb4LE3_mwXRlB4AaABAg
# 0
# I too missed your videos, always interesting to watch what is happening on the farm .
# Ugys10Z2RynSs106bfl4AaABAg
# 0
# Good to see, that you got the lagoon emptied, before the bad weather.
# Ugw5c3Y39F3PsPe9PBZ4AaABAg
# 0
# Using crap to clean crap that made me laugh never thought I'd hear someone say that but here we are
# UgwK3Pk5Nvb7TJhDR6t4AaABAg
# 0
# Do you have any bulls
# UgzwuZ5OxYb7boirblB4AaABAg
# 0
# the main element  plants  & crop  get from manure is Nitrogen which is present in manure in the form of Ammonia #
# Ugw-ysYOY-tmJ_ITf594AaABAg
# 0
# Hi I am from  Bangladesh....❤
# UgzaXxQEEFm5kXiuYrR4AaABAg
# 0
# I imagine your Dairy Farm is pretty popular in the neighborhood during crap flinging time over the fields.  It is what it is.  :)
# UgznJ9zxhoqwsVrUhZJ4AaABAg
# 0
# You dont use robots for milking? I am no dairy man, but most dairy farms here in norway have one or two robots.
# UgzCFFhj8O3BTXwxmth4AaABAg
# 0
# Hi Jan how much m³ minure per Hektar did you spread?
# UgyV2B0SSDhWX_albhB4AaABAg
# 0
# 👍
# UgyOafIjmLO3E3apINF4AaABAg
# 0
# I held my breath while you were In the pit it's so dangerous I've missed your videos would love to see the cow's and babies they have such beautiful patterns. You are always so busy but please try and do more videos
# Ugzpyy-jAtMcJZQkRvl4AaABAg
# 0
# Hay Canada Dairy Farmer.
# Love the video of the cow barn crap tank clean out. You are one smart farmer using that crap hydro wond to clean out that barn holding tank. Keep warm that Artic express can rock you back on your heals some times. Thank You very much for the video. Please Take Care of your self Plus Be Very Care Full around all Farm Equipment.
# UgxTHZsNRuvQ659NP8F4AaABAg
# 0
# 2100 acres of land.  for 300 cows does it take that amount acre for feed for 300 cows?? love your videos
# Ugyau3Cy9zWPhzBJqz14AaABAg
# 0
# I was entertained for 12 minutes by watching 🐂💩 lol
# Ugw5AOI-yjfVda4i-Dh4AaABAg
# 0
# Where the smell-a-vision at?
# UgzrHJXYiw3XeSyXj694AaABAg
# 0
# 👍👍👍👍👍👍
# Ugwspyu3tZc8zur1ByZ4AaABAg
# 0
# Don't you need ventilation when climbing in a pit?
# UgyNj9QOH_-UlLK-rPl4AaABAg
# 0
# Also you need an oxygen meter reader. You could have died. Even being just above.
# UgwX1-DvMgBpPOqVcJV4AaABAg
# 0
# He has been not as happy in his last couple videos. He was faking to be happy to keep the channel going. Stay strong.
# UgzZIVQ0EQAM5dE-sEh4AaABAg
# 0
# Our thoughts and Prayers are with the farmers of BC who have lost their entire farms and numerous cows have drowned in their barns due to flooding. Please remember and support them in whichever way you can.!!!
# Ugxmo6hQdlIW19IiD2J4AaABAg
# 0
# Been waiting to see a new video from you...nice to see you're back!
# UgxniLVFrxyds3Y7CKd4AaABAg
# 0
# I didn't get notifacation, this has been up  a day already and I only found it by chance.👍
# Ugz3AJ0QJ4Z-OpvLEeN4AaABAg
# 0
# That really is a really nice tractor. John Deere, Kubota etc will be watching closely I can guarantee that! Great content. Hope the KCS rail merger goes through. Sorry to hear about the catastrophe in British Columbia.
#
# *SAFETY FIRST ALWAYS!*
# UgxerUP8uquEM15njRJ4AaABAg
# 0
# Welcome back Jan! Missed the videos, I follow your sister and watch her video’s! 🇨🇦
# Ugwuxsmxm69ppeZVw3Z4AaABAg
# 0
# I wouldn't have gone into that pit.  Confined space.  I would have lifted the lid and laid on the ground up side downand.  Then tilled and it tighten the bolts that way.
# UgzkqticCTJo4xutb9B4AaABAg
# 0
# Oh wow this is cool video
# Ugw_z7e2AKrdZ1eECPt4AaABAg
# 0
# Always admire the ingenuity of farmers, great work.
# UgwC2FVgpQKC8uNqRFN4AaABAg
# 0
# Hey Jan! Never been so glad to see a YouTube video in my life 😄😄 I too was worried something happened to you. Glad to see you doing well.
# UgyIybKC9satmd4octZ4AaABAg
# 0
# Thanks for your videos!
# UgyZFY1YvuYEmXLQXhh4AaABAg
# 0
# Jan, I humbly suggest your next big investment for the farm should be a liquid/solid separator with a sand recovery system. Much safer for everyone.
# UgxDOxktzmnrGG5SrSR4AaABAg
# 0
# Good job 👍
# UgyV6K1gWnKNget7lZF4AaABAg
# 0
# https://www.youtube.com/watch?v=pofYFbS8mmo
#
# mini tractor
# UgwqnRiUVdGVZFJcCYp4AaABAg
# 0
# Put a smaller pipe at end of pipe into the pit to flush out ever. More water force.
# UgzAHg9VnsGVpDRuF-l4AaABAg
# 0
# Organik gübre çok güzel.
# Ugym2gNK989AtXuXJJp4AaABAg
# 0
# maybe try finding an old fire nozzle  you could lower it in with a handle welded on top so you can lower it in the pit and turn it and  because of the reduction the pressure would be better.
# UgzHlQunTG5DYljGbTx4AaABAg
# 0
# Hello Jan!!! Wow, so so good to see you back!!! I hope and pray all is well with you and the rest of the Kielstra clan. You have been missed a great deal. Your videos are always honest and open, showing us all that is involved for dairy farmers. It is interesting and informative seeing how dairy practices are the same yet different in different parts of Canada and US. It is very rewarding watching a new generation of diary, beef, and  grains/produce farmers and the dedication, knowledge, and love of being a farmer is all about. God bless you all and glad to see you posting again. Best wishes from St. Clair, Michigan ( across the river from Sarnia, Ontario).
# UgycOOee6Tb0pWQJm9N4AaABAg
# 0
# Drone beelden zijn altijd on point!
# UgzTZ5eVscXZVx84FUd4AaABAg
# 0
# 👍
# Ugy72ejuIozLj87c-TN4AaABAg
# 0
# Beautiful missionary beautiful work dairy farming Mohammed Salim Punjab India
# UgxoAlUwV7LlX-tJ-Op4AaABAg
# 0
# Bro. It's called pvc pipe not pcv😅😅😅😅
# Ugy0qTE2YP_14ggvBYl4AaABAg
# 0
# i had over a year of your videos to catch up to, finally made it :D
# UgyUG6gY4SXW5FYuNRV4AaABAg
# 0
# What ever happened to the project to build the fence around the pit?  I still see the metal poles up.
# Ugwcp8KhMyluPOsT8yZ4AaABAg
# 0
# Thanks for posting …….
# UgwXMeJ2vrQgYbNNtmJ4AaABAg
# 0
# Glad to see you  finally got around to make a update video.
# UgwuviIBvs0eRPn0Vq54AaABAg
# 0
# Looks like someone needs a pair of hip-waders 🙈😵
# Ugze2WJTnAzYX_BQo5N4AaABAg
# 0
# Looks like someone needs a pair of hip-waders 🙈😵
# UgxKYthjY9Yy9hkKI0l4AaABAg
# 0
# Thanks for the Video, even if was a crappy one , I enjoy this shit. Aloha from the Big Island 🤙🏼🤙🏼
# Ugx0yXrEG4-ymBxgYJ94AaABAg
# 0
# Please make a comprehensive video about your manure management starting from washing barn to end with pit clean up.
# UgxLXHfcOJFR5swoiMx4AaABAg
# 0
# Guess I should say I’m glad you are back
# Ugx8g3SS_h_p9VFisml4AaABAg
# 0
# Seems like you might benefit from a settling run for the sand .
# UgxPPTKbbEwyuP-5reV4AaABAg
# 0
# Where have you been dude?
# Ugx9b_OaCmzkFJvW1Tt4AaABAg
# 0
# Keep  up the good work. Glad you all work  together  to keep farm going.
# Ugx22OtOlSYP_Axc_cV4AaABAg
# 0
# I am thankful that the magic of the internet does not include SMELLOVISION!
# Ugyuu2Zhsg_yt8EtVLp4AaABAg
# 0
# PLEASE, at least watch farming safety videos, you do to many unsafe acts. You n dad are leveling up the production game👍, but I'm sorry your safety game is trash. (Saying this with 💛)
# Ugz3T1ovZGqr1RzGdEB4AaABAg
# 0
# So thankful I don't have smell-o-vision!!
# UgxNs36A1_OO9iDlnnR4AaABAg
# 0
# Hi Jan can you tell me how you know that you are giving the cows a balanced diet and how you know that your mix of feed is correct with giving them the correct mix of vitamins, nutrition and what is your feed mix for the dairy cows to ensure you get happy cows who drop high milk production
# Ugyco5XExraQwxjsflt4AaABAg
# 0
# Not very interesting video. Used to be good.
# UgxYptZfwEmchEBw5Id4AaABAg
# 0
# Good to see you Alain, Jan! Be careful climbing in that pit - don’t want any gasses knocking you out or worse, buddy! Great video! Happy day to see a post from you and your sister!
# UgwsKR_gKso2-oHhjgB4AaABAg
# 0
# I rarely see jan responding to the questions in the comments.
# Ugz7dQY7ncYOzTwK10t4AaABAg
# 0
# Great job Jan.  Glad YouTube doesn’t have smell-a-vision!
# UgxKi6ikbEvOoPCSWhx4AaABAg
# 0
# Yay, Jan is back.
# UgyE9aQHHABdhAtTN-Z4AaABAg
# 0
# Gave up on the pit fence?
# UgwBDeQhokgbj99aSzt4AaABAg
# 0
# Great video Jan
# UgzkcTYfCWf94tbWnfV4AaABAg
# 0
# 10ft deep and you are walking on quick sand without any safety gear. You have only one life. Use it wisely.
# Ugyo5IEE60D9LQVg7Uh4AaABAg
# 0
# PVC pipe, you’re welcome 😋
# Ugwqk4zShtNXuMAzGZJ4AaABAg
# 0
# spanjer agitators you need
# UgzmepItYmwYHu87eGR4AaABAg
# 0
# Delt with some of the same things in the 60s and 70s when I was on the dairy farm in Lynden Wa.
# UgwA3lfw9dUU4-_QaQB4AaABAg
# 0
# I'm sure we enjoyed watching this video more than you enjoyed making it Jan! The smell didn't bother me a bit!
# UgynyvOek-NQlmc666R4AaABAg
# 0
# Ah! The smell of liquid manure from the neighbors farm. Usually means at least a 12 pack of an adult beverage especially if the wind is in the right direction.
# UgzORM3eGEFdM0Dt7G54AaABAg
# 0
# Wow! Good job on that pit.
# UgzpCihbt0YJ40wXGMV4AaABAg
# 0
# Jan you make working with poop such an interesting experience. Thanks.
# UgycoweeGH0j6BnOMhh4AaABAg
# 0
# Did your dad want to negotiate your salary again when you were down on that plank in the manure pit? ;)
# Ugxqvq9BTmVZ0tLDhV54AaABAg
# 0
# 👍
# UgxogYkM0jjUVcubCoZ4AaABAg
# 0
# Do you ever completely clean that pit out..including all the sand???
# Ugyb-Yqk8Zu5phQy-x94AaABAg
# 0
# You should look into getting a bedding material that’s biodegradable when it gets wet when scraping the alleyways in your barn that way you don’t have to use sand in your beds
# UgxuUzhVvW6F4s6Bq554AaABAg
# 1
# sorry Jan it is in the night 7 degrees not minus hehehe
# UgwxCUHIfLFiE_CTIwt4AaABAg
# 0
# Hi Jan,nice to see you again,thanks for posting this very interesting video,wow what a big manure tank !! it is over her not so cold as in Canada the day over about 10/12 and in the night -- 7 degrees.!!
# UgyL3YBDRP9hgThI6Pt4AaABAg
# 0
# ❤️
# UgywqKNxGKHIigCZa-54AaABAg
# 0
# Prayers to all the dairy farmers in Abbotsford,BC. Thousands livestock lost to floods. Farmers being told to dump milk
# UgzgH9XMNfWfcQcuPct4AaABAg
# 1
# Jan, missed you, thank you for the great video. Always enjoy the drone footage
# Ugy04Py9qhybEQVbvKp4AaABAg
# 0
# Jan, where you been? I was begining to think you had stopped doing vids. Great to see you back bud
# UgzAXlLa3Zeu4NEu1754AaABAg
# 0
# will you be ice skating soon?
# UgxsDep_8W8h84Fhy_N4AaABAg
# 0
# Great video as usual!!!!
# Long time no see!
# The weather  forecast is more often wrong when forecasting good weather but is spot on when it comes to forecasting crap weather!!!
# It is the only job on the planet  where  you can be consistently  wrong and still keep your job!!!!!
# Ugz1wfhE23VwksdAcat4AaABAg
# 0
# will you not kill all the living manure bacteria spreading it while it's freezing ?
# UgxNzQ_-6OK_42Bgb-54AaABAg
# 1
# Hi Jan, great video.  Glad to see you.
# Ugy2PsigjIHDWc02rLV4AaABAg
# 0
# Really enjoy your channel. I hope you realize how many of us are entertained with your content! Keep up the great work!
# Ugwfs4EEsWn4Nn19E3Z4AaABAg
# 0
# Awesome video. Been missing you.
# UgwHAtDQKsCD7AAcPxV4AaABAg
# 0
# It’s so nice to see you again hope all is well
# Ugxu4z2Q7zf0ggeG5114AaABAg
# 0
# It would be nice if you could reclaim the sand
# Ugz4oHJpM3UuQ2smt454AaABAg
# 0
# 👍
# Ugwtdu2If-VrfGsctGN4AaABAg
# 0
# I always enjoy your videos Jun. ✅.  My question has to do with the manure you are spreading on the fields which also includes a lot of sand that is being fired out there. If a farm already has sandy soil, is there a possibility that over time this additional sand will impact the bushels per acre that can be produced?  Thanks.🤓.
# UgzerMlpAdz8yFyQ4fh4AaABAg
# 0
# Great idea to clean the pit under the barn. Was afraid you might be swimming for a second there. Good to see you.
# UgwQywAMwt86sW8JNUV4AaABAg
# 0
# Great video . Best wishes. 👍👍👍👍
# UgwHAwvedj7cXhoy4Ip4AaABAg
# 0
# Dang, where you been? Been missing ya!!!
# Ugx6qyhxnKeEtbP_A0d4AaABAg
# 0
# As you can see from the comments, you have been missed. Your videos never get boring.!!! So glad to see your smiles.
# UgwFx6uFbU0akKsxp9x4AaABAg
# 0
# Good to see you back was that a invisible force field fence around the lagoon😂😂😂 have a great winter
# Ugzt6qDSTQp2c0ovUk94AaABAg
# 0
# PCV?
# UgyPe_RXUjrPHpYyFlx4AaABAg
# 0
# Please Jan, never get in a pit due to the gases. If you absolutely have to go in, at least get a harness or rope on yourself so you can be pulled out immediately if you start to feel faint or pass out.
# Ugy8emAqQmjb2M_YfgB4AaABAg
# 0
# glad nothing was wrong. good video
# Ugwl2w3urX0ACk6xvCd4AaABAg
# 0
# yee ha shit day
# UgwXVCZzQCJNv4h5uLl4AaABAg
# 1
# jan stop sending cold air to upstate ny lmao
# UgxHrP4kXIYVk7l7AYh4AaABAg
# 0
# Good to see you really have enjoyed you sisters show .
# UgyWg0fNCfc7zMMJXLB4AaABAg
# 0
# That was just stupid going into that tank , that plank could have sank and you would have drowned or you could have been over Come by gasses
# UgzGRQhtO1F_GHwfmHd4AaABAg
# 0
# I loved how he called the plastic pipe PCV😂😂😂
# UgyfGerq7Ff4Jhd0enF4AaABAg
# 0
# I see fence is still not put at shit pit  going on two years  lol  lol 😆 😂
# Ugz40wDq18yCTWMLmNR4AaABAg
# 0
# Glad you are back young man
# ..always a plus when you post...thank you for your efforts....😎👨‍🌾👍
# UgzS5_0_nppGVOvuakZ4AaABAg
# 0
# That sand must be so abrasive on equipment?
# UgwXFtg5CoxSl5Kuxa94AaABAg
# 0
# All’s well that ends well but  we had a couple of city workers die right quick in a pit like that.
# UgzkUEzXaOrkt96yWfx4AaABAg
# 0
# You have to loose that sand and switch to straw instate. 😉
# Ugy16SpWQSPndm68UGt4AaABAg
# 0
# Why not try and get the sand out from that hole with a backhoe instead.  That way you would be pulling out pure sand and not move it to the large pit where it is still a problme
# UgxLM7Ql1XN0oUwbLjV4AaABAg
# 0
# At what point will you have to remove sand from the pit?
# UgyoW5661YIU1jHRYTh4AaABAg
# 1
# Great video as usual Jan.
# UgxuXvSJhvc-NwHTotd4AaABAg
# 0
# been wondering where you disappeared to, then I saw the back of the new barn and I imagine that's taken up alot of your time in the last couple of weeks
# UgwVMh48Ox04ixSLSVF4AaABAg
# 0
# You are one lucky boy... H2S and or other heavy gasses and down you go.  Confined spaces entries require a gas test as well as a spotter and harness so they can get you out.  Be careful bud... you dodged a buttle that time.
# UgwfHq9hk8C_5NrFGb54AaABAg
# 0
# Git-er-done, eh !!
# Ugz0z8oSR76nCmFwRtV4AaABAg
# 0
# Hello Jan, nice to see you.
# UgwKqjH2N66bzf6LbGl4AaABAg
# 0
# Missed you, glad to see you back.
# Ugy6DmZ1PswUiDoc5m54AaABAg
# 0
# Great to see another video thanks for posting
# UgwN8C3mhGO0uNV6Mix4AaABAg
# 0
# NEVER go into the manure pit.!!!! There are gasses
# UgwN9u_xFHUyPANIivl4AaABAg
# 0
# When are you gonna finish the manure fence🤣
# UgycNFJTki20y_asnTp4AaABAg
# 0
# That’s the only cow product vegans eat! 100% plant base cow pie .
# UgyP1WWO0qjZ79hffHF4AaABAg
# 0
# Do you just get used to the smell. Stirring that pit has to create quite a smell.
# UgyghUPIrhF00U01MbF4AaABAg
# 0
# Not always a bad thing that Smell'o vision is not a thing yet :) But you guys did a good job.
# Ugy8a35sRG_GnJXFvdx4AaABAg
# 0
# Smart farming! Brilliant video 💪🏻 🏴󠁧󠁢󠁷󠁬󠁳󠁿
# UgyeewkDrkWIya5txMh4AaABAg
# 0
# Sure hope you weren't hit too badly with the storm. Always wishing you well. Enjoy both you and your sister.
# UgwvKIs9WgifdEaND9l4AaABAg
# 0
# I was wondering how the new addition and your outdoor herds survived yesterdays blizzard. I can usually hear your cows from my back deck but with the wind yesterday I could not even hear the trains. Hope you are not out today looking for dislodged tin. Thanks for the video.
# Ugw8Qo-0i3p8xIhOu2J4AaABAg
# 0
# Thanks my  friend for sharing the update on the dairy work before the winter period.👍
# Ugw6lSh8tIjgAH-_ad14AaABAg
# 0
# That buck stops with the ones who work hard. Happy Thanksgiving for Bakersfield California USA.
# UgzyY06xU8zzQHhpSHV4AaABAg
# 0
# 2x20s uninteruptable advertisements in the beginning, do you have a hand in that?
# ( last time, next time i quit )
# Ugx-_2deo9m77IhnDRF4AaABAg
# 2
# Remember! Humans have NO mechanism to detect lack of oxygen- until you pass out anyway. (We can only detect increased carbon dioxide) please NEVER enter confined spaces w/o a harness & buddy to haul you out. Blessings!
# UgyIlLrdeBy6_kFMxyh4AaABAg
# 2
# Good to see ya.
# UgyECuDwKXjno2NJ1nR4AaABAg
# 0
# Living in a cold part of the world in Sweden just wondering what temperature you have in the pit in mid winter, Jan? Can't you have a static pumpsystem with equipment over manure level in a heated space and just drain back into lagoon when you stop pumping?  With stationary pressure pipes along sides in the lagoon with valves and nozzles under surface I can't see it as impossible to get everything out even in deep freeze times. If you can choose ratio between pumping out and for recirculation then it may solve most problems.  I don't really know your specific situation as I'm not used with sand bedding.  Low slanting bottom or pits in bottom of lagoon and suction pipes from there? Must be the same situation in the slurry pit at barn. (I'm a bit of a pumping nerd! :)
# UgydJFLe-71cXka6igl4AaABAg
# 1
# Hey Jan..try a reducing coupling on the end of the pipe to create a little more pressure to reach far end of pit..maybe double clamp your hose too so you dont get covered in shite lol
# UgyzOcI_RSGSSj3l6HB4AaABAg
# 0
# Of all the shitty jobs on a farm, hauling manure is the shittiest. 🤣
# Ugzih0bVl-okDQELr8Z4AaABAg
# 0
# Welcome back.  You were missed.
# UgxihMIkKOLDaVZKN5N4AaABAg
# 0
# Regular fertilizer is somewhat expensive these days( depending on a number of factors ). With as big of a manure pond that you have, have you thought about selling some of that black, smelly gold stuff to other farmers? Even if you sell it for $1.50 per gallon, your farm should get back quite a bit of money from all the expenses incurred from doing business.
# Ugz2-DTPc_Qky4ecCtV4AaABAg
# 2
# How long do your wellies last?
# UgzsYOjuxDe5eBKfU-d4AaABAg
# 0
# What your review on the Dunlop purfort thermo?
# Ugwt42aYlD9UeyTdD0B4AaABAg
# 0
# Id redesign pit so a backhoe can be used to dig out sand.
# UgzExLrx2c2wLYX_XqR4AaABAg
# 0
# Nice to see you again, as always. Great video, as always!
# Ugx55WwRKtvK_J86Eg94AaABAg
# 0
# Thanks for the update Jan.  Nice clean farm...
# UgxKSN1Zj0uj1Jy3EuN4AaABAg
# 0
# Good job with the sand removal.
# Ugz4LO74dAbCas_XrT54AaABAg
# 0
# Love the video 😍😀
# Ugzc9hwbEyHSKQ4KwXh4AaABAg
# 0
# love it :)
# UgyEfTDk_VOk3zg7HPp4AaABAg
# 0
# Greetings to all from Florida! Makes an old farm hand happy to see you guys in action, Jan! Excellent job cleaning that barn's manure pit. Great drone footage, too! Take care!
# UgxHK915IZRhQavaUnp4AaABAg
# 0
# Horrible job!!!
# UgyJntAbVYD5bSQWJ654AaABAg
# 0
# Never so glad I can't smell your work as when you're hauling manure!
# Took some guts to crawl into that pit!!! Drowning in the stuff would probably be my worst nightmare if I was there.
# Edit: seeing other comments, the fumes are just as nasty. Careful!
# Ugztse48Hm73yLNOFdh4AaABAg
# 0
# Can you introduce enzymes to break down the manure?
# UgwsF25F8TmaWlzF2mh4AaABAg
# 0
# It's a shitty job but you're just a man for it 👍🤠 🇨🇦💪💪🐄🥛🥛
# UgzsDRSDCeCC7XtKKER4AaABAg
# 0
# My uncle and grandpa haul manure for you!
# Ugz7SPkTGPOj3W7hSSt4AaABAg
# 0
# That’s what you call a poopie job!
# UgxBqYn_Bftwn88IMP14AaABAg
# 0
# Why not clean the pits and lagoon to the bottom? You are limited when and how much you can  remove, but not limited in the amount and timeframe to fill them up.
# UgxzXZtSfsFiu7hIAsp4AaABAg
# 0
# Good to see you back but not happy seeing you standing close to the spinning PTO as it's and accident waiting to happen  get the chains on and the guards on as your better off with your limbs attached
# UgxdOukKSdpey4fCqNR4AaABAg
# 1
# ...Cheers...
# UgwZyn8Pt2LWb3vKTXh4AaABAg
# 0
# LOOKS LIKE A 360 DEG. RECYCLE. FIELD TO COW, COW TO FIELD, FIELD TO COW. FANTASTIC SPREADER.
# UgzLJ8RXaILF-OhyuwZ4AaABAg
# 0
# I would think a loop off of your pit pump onto a nozzle that could be turned 360 degrees would  be ideal to breakup the sand buildup in that pit - that way you dont need to open the lids and a valve setup could divert some manure to breakup and the rest out to the lagoon.
# Ugzlp_HnI2EYyjQeEkp4AaABAg
# 0
# Nice one 👌🏻
# When do u put the fence on around the manure pit? U already prepared the iron poles 🤷‍♂️
# Ugy0DHBGkpbuNhDOcCB4AaABAg
# 0
# If you pump down the pit were are you going to play hockey
# UgzHVdQW70Z9qazaXfh4AaABAg
# 0
# Yes! Been wondering what happened to you!
# Glad your back. It’s great to see that the dairy farming is
#  still operating, and that you are Ok.
# Ugww_8a_kxvR8xuO3dp4AaABAg
# 0
# bedding cow pack with sand is not a good idea bcuz it just thicker and gets hard wich makes it harder and much more work for you guys ............... u should try sawdust instead way much softer and easier .
# UgztD9F3Q6ySQPLMsLV4AaABAg
# 0
# 👍👌🇨🇦❤, another Sask boy, me too
# UgxnF7-sTb1T-0GG31d4AaABAg
# 0
# Hallo Jan were have you been? long time no video.
# It is fun to see you again playing with shit
# UgzC1cu_7tN3U6tVCPR4AaABAg
# 0
# What's that fuzzy stuff on your jaw? 😆
# Ugy4MRKtnSncV2PIMjx4AaABAg
# 0
# Jan why dont you those stra like Eric on 10th generation   and is it posible to fead horses  silage???
# UgxAeJTYi7ga5OCJ23F4AaABAg
# 0
# Excellent update on what has been happening on your dairy farm. Good to see you back. I'm expecting to see snow in the next video. 👍🚜🐄 🇨🇦 🇳🇱 🇦🇺
# UgyItRdNlGb3QXsHNnl4AaABAg
# 1
# You always have such great drone footage 👍  Nice work
# Ugy0RFJ5XvF7bZeTs3d4AaABAg
# 0
# I can't even imagine the smell, not sure how you do it, good to see you back
# UgwkqDsv5OQxbdXGyKF4AaABAg
# 5
# And who wrote 'detailed job description' for in-pit duty??
# UgygpooH4c4Y1nPjSxp4AaABAg
# 0
# I ain't Gon kap I missed you from uploading videos Jan hope you're well
# Ugwg_yVzztrTRK0TCt94AaABAg
# 0
# Are there any toxic gases produced by the sewage sludge?  . . .  I was just wondering.  I was thinking of your health.
# UgwnWQa-UN8PMgSCant4AaABAg
# 0
# 👌👌
# UgzsKESerGPuokrWdlF4AaABAg
# 0
# Put a reducer on the pipe. That might give you the distance and power to get the last bit
# Ugy4yndK5cM0MIVcJAx4AaABAg
# 0
# Man!   I'm not trying to tell you how to run your operation but PLEASE be careful crawling into an enclosed manure pit.  Fire and Rescue here has had to recover 2 bodies this last year  after farmers were overcome by gasses from manure pits.  I know it might not seem bad at first when you go in ,  but you can die within minutes.   You have a great channel man,  but please be careful!
# UgxUUy1Mr3dz0nN2Sdp4AaABAg
# 4
# been missing your videos , but understand you are so busy . Another great video , thanks for sharing !
# UgxPoUTtL7RJdeF8PSF4AaABAg
# 0
# Hey, where you been?  Thought you were sick.
# UgwkVcXMyR_YIsz3W5J4AaABAg
# 0
# My dad hauls manuer for you
# UgxQlVnLIwaqqtcoWhp4AaABAg
# 0
# Hi Jan. Been wondering and worried about where you’ve been. Glad to see you!!❤️
# UgzKsa7DFuaqVi7r8Op4AaABAg
# 0
# Same sh!t, different day...
# UgznWFqjdyBSzvaU_dV4AaABAg
# 0

# %%
type(response)
# Out:
# dict

# %%
response.keys()
# Out:
# dict_keys(['Comments', 'Comment ID', 'Reply Count'])

# %%
import pandas as pd

# %%
df= pd.DataFrame.from_dict(response)

# %%
df.to_csv("SDK.csv")

# %%
df1= pd.read_csv("SDK.csv")

# %%
df1.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0                                           Comments  \
# 0             0  Farming, Fixing & Fabricating channel has some...
# 1             1                                   It’s PVC not PCV
# 2             2  To clean that pit at the barn you should rent ...
# 3             3  I went in here to comment and noticed Alex Dra...
# 4             4  I would just make sure you carry a oxygen moni...
# ..          ...                                                ...
# 188         188  been missing your videos , but understand you ...
# 189         189       Hey, where you been?  Thought you were sick.
# 190         190                        My dad hauls manuer for you
# 191         191  Hi Jan. Been wondering and worried about where...
# 192         192                        Same sh!t, different day...
#
#                      Comment ID  Reply Count
# 0    Ugzw-v1WGpnjr2-Xv2l4AaABAg            0
# 1    Ugz2TltI1vOdIWkhAml4AaABAg            0
# 2    Ugy03norOg4_escUAZl4AaABAg            0
# 3    Ugz18yAPJ-GiU9BboA54AaABAg            0
# 4    UgwyDGnrYQ3gqH5YIm94AaABAg            0
# ..                          ...          ...
# 188  UgxPoUTtL7RJdeF8PSF4AaABAg            0
# 189  UgwkVcXMyR_YIsz3W5J4AaABAg            0
# 190  UgxQlVnLIwaqqtcoWhp4AaABAg            0
# 191  UgzKsa7DFuaqVi7r8Op4AaABAg            0
# 192  UgznWFqjdyBSzvaU_dV4AaABAg            0
#
# [193 rows x 4 columns]>

# %%
import demoji

# %%
comments= pd.read_csv("SDK.csv")

# %%
comments
# Out:
#      Unnamed: 0                                           Comments  \
# 0             0  Farming, Fixing & Fabricating channel has some...
# 1             1                                   It’s PVC not PCV
# 2             2  To clean that pit at the barn you should rent ...
# 3             3  I went in here to comment and noticed Alex Dra...
# 4             4  I would just make sure you carry a oxygen moni...
# ..          ...                                                ...
# 188         188  been missing your videos , but understand you ...
# 189         189       Hey, where you been?  Thought you were sick.
# 190         190                        My dad hauls manuer for you
# 191         191  Hi Jan. Been wondering and worried about where...
# 192         192                        Same sh!t, different day...
#
#                      Comment ID  Reply Count
# 0    Ugzw-v1WGpnjr2-Xv2l4AaABAg            0
# 1    Ugz2TltI1vOdIWkhAml4AaABAg            0
# 2    Ugy03norOg4_escUAZl4AaABAg            0
# 3    Ugz18yAPJ-GiU9BboA54AaABAg            0
# 4    UgwyDGnrYQ3gqH5YIm94AaABAg            0
# ..                          ...          ...
# 188  UgxPoUTtL7RJdeF8PSF4AaABAg            0
# 189  UgwkVcXMyR_YIsz3W5J4AaABAg            0
# 190  UgxQlVnLIwaqqtcoWhp4AaABAg            0
# 191  UgzKsa7DFuaqVi7r8Op4AaABAg            0
# 192  UgznWFqjdyBSzvaU_dV4AaABAg            0
#
# [193 rows x 4 columns]

# %%
comments['clean_comments']= comments['Comments'].apply(lambda x: demoji.replace(x, ""))

# %%
comments.head()
# Out:
#    Unnamed: 0                                           Comments  \
# 0           0  Farming, Fixing & Fabricating channel has some...
# 1           1                                   It’s PVC not PCV
# 2           2  To clean that pit at the barn you should rent ...
# 3           3  I went in here to comment and noticed Alex Dra...
# 4           4  I would just make sure you carry a oxygen moni...
#
#                    Comment ID  Reply Count  \
# 0  Ugzw-v1WGpnjr2-Xv2l4AaABAg            0
# 1  Ugz2TltI1vOdIWkhAml4AaABAg            0
# 2  Ugy03norOg4_escUAZl4AaABAg            0
# 3  Ugz18yAPJ-GiU9BboA54AaABAg            0
# 4  UgwyDGnrYQ3gqH5YIm94AaABAg            0
#
#                                       clean_comments
# 0  Farming, Fixing & Fabricating channel has some...
# 1                                   It’s PVC not PCV
# 2  To clean that pit at the barn you should rent ...
# 3  I went in here to comment and noticed Alex Dra...
# 4  I would just make sure you carry a oxygen moni...

# %%
comments.to_csv("SDK_clean.csv")

# %%
import pandas as pd
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Jilian\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
df1= pd.read_csv("SDK_clean.csv")

# %%
df1.head(20)
# Out:
#     Unnamed: 0  Unnamed: 0.1  \
# 0            0             0
# 1            1             1
# 2            2             2
# 3            3             3
# 4            4             4
# 5            5             5
# 6            6             6
# 7            7             7
# 8            8             8
# 9            9             9
# 10          10            10
# 11          11            11
# 12          12            12
# 13          13            13
# 14          14            14
# 15          15            15
# 16          16            16
# 17          17            17
# 18          18            18
# 19          19            19
#
#                                              Comments  \
# 0   Farming, Fixing & Fabricating channel has some...
# 1                                    It’s PVC not PCV
# 2   To clean that pit at the barn you should rent ...
# 3   I went in here to comment and noticed Alex Dra...
# 4   I would just make sure you carry a oxygen moni...
# 5   Jesus guys   so dangerous getting into a slurr...
# 6      Do you always use the pump in the same corner?
# 7   I sure would hate to live down   wind  from yo...
# 8   Make it easier on yourselves, pump the water o...
# 9   When are you completing the fence/guard rail s...
# 10                                        PVC not PCV
# 11  Glad to see you're back I love watching your c...
# 12                      Good one, Jan & Dima! Cheers!
# 13  Not wearing respirator or tied off for safety ...
# 14                             “PCV”, totally not PVC
# 15  I too missed your videos, always interesting t...
# 16  Good to see, that you got the lagoon emptied, ...
# 17  Using crap to clean crap that made me laugh ne...
# 18                              Do you have any bulls
# 19  the main element  plants  & crop  get from man...
#
#                     Comment ID  Reply Count  \
# 0   Ugzw-v1WGpnjr2-Xv2l4AaABAg            0
# 1   Ugz2TltI1vOdIWkhAml4AaABAg            0
# 2   Ugy03norOg4_escUAZl4AaABAg            0
# 3   Ugz18yAPJ-GiU9BboA54AaABAg            0
# 4   UgwyDGnrYQ3gqH5YIm94AaABAg            0
# 5   UgwZXGdJHSJOMFPS1Bp4AaABAg            0
# 6   Ugxfw8ZLGc77VDVS-V94AaABAg            0
# 7   UgySuaRKaj67QlYZPD54AaABAg            0
# 8   UgwsGo3utD-G0Y_w5J54AaABAg            0
# 9   UgxWWvBV7Cqa2i8w4-N4AaABAg            0
# 10  UgyYnS_xx0uOiu7m7_h4AaABAg            0
# 11  Ugz9K-7Qe7YW_UOjN2p4AaABAg            0
# 12  UgzL5Flgc27xGlos0td4AaABAg            0
# 13  UgxWDl5iZcQ0Dpyf8Vx4AaABAg            0
# 14  UgzwI3gb4LE3_mwXRlB4AaABAg            0
# 15  Ugys10Z2RynSs106bfl4AaABAg            0
# 16  Ugw5c3Y39F3PsPe9PBZ4AaABAg            0
# 17  UgwK3Pk5Nvb7TJhDR6t4AaABAg            0
# 18  UgzwuZ5OxYb7boirblB4AaABAg            0
# 19  Ugw-ysYOY-tmJ_ITf594AaABAg            0
#
#                                        clean_comments
# 0   Farming, Fixing & Fabricating channel has some...
# 1                                    It’s PVC not PCV
# 2   To clean that pit at the barn you should rent ...
# 3   I went in here to comment and noticed Alex Dra...
# 4   I would just make sure you carry a oxygen moni...
# 5   Jesus guys   so dangerous getting into a slurr...
# 6      Do you always use the pump in the same corner?
# 7   I sure would hate to live down   wind  from yo...
# 8   Make it easier on yourselves, pump the water o...
# 9   When are you completing the fence/guard rail s...
# 10                                        PVC not PCV
# 11  Glad to see you're back I love watching your c...
# 12                      Good one, Jan & Dima! Cheers!
# 13  Not wearing respirator or tied off for safety ...
# 14                             “PCV”, totally not PVC
# 15  I too missed your videos, always interesting t...
# 16  Good to see, that you got the lagoon emptied, ...
# 17  Using crap to clean crap that made me laugh ne...
# 18                              Do you have any bulls
# 19  the main element  plants  & crop  get from man...

# %%
df1.clean_comments.isnull().sum()
# Out:
# 7

# %%
df2= df1.dropna(subset=["clean_comments"])

# %%
df2.clean_comments.isnull().sum()
# Out:
# 0

# %%
sentiment = SentimentIntensityAnalyzer()
sentiment.polarity_scores(df2.clean_comments[0])
df2['SDK_sentiment'] = df2.clean_comments.apply(lambda x: sentiment.polarity_scores(x))

# %%
df2['SDK_neg_sentiment'] = df2.SDK_sentiment.apply(lambda x: x['neg'])
df2['SDK_pos_sentiment'] = df2.SDK_sentiment.apply(lambda x: x['pos'])
df2['SDK_comp_sentiment'] = df2.SDK_sentiment.apply(lambda x: x['compound'])

# %%
# most positive 
df2.sort_values(by=['SDK_comp_sentiment'], ascending=False)[['clean_comments']].head(10)
# Out:
#                                         clean_comments
# 50   Hello Jan!!! Wow, so so good to see you back!!...
# 159  Greetings to all from Florida! Makes an old fa...
# 26   Hay Canada Dairy Farmer. \nLove the video of t...
# 187  Man!   I'm not trying to tell you how to run y...
# 188  been missing your videos , but understand you ...
# 100  Really enjoy your channel. I hope you realize ...
# 139  Sure hope you weren't hit too badly with the s...
# 11   Glad to see you're back I love watching your c...
# 82   I'm sure we enjoyed watching this video more t...
# 72   Good to see you Alain, Jan! Be careful climbin...

# %%
# most negative
df2.sort_values(by=['SDK_comp_sentiment'], ascending=True)[['clean_comments']].head(10)
# Out:
#                                         clean_comments
# 97   Great video as usual!!!!\nLong time no see!\nT...
# 148  Of all the shitty jobs on a farm, hauling manu...
# 5    Jesus guys   so dangerous getting into a slurr...
# 117  That was just stupid going into that tank , th...
# 146  Living in a cold part of the world in Sweden j...
# 161  Never so glad I can't smell your work as when ...
# 160                                    Horrible job!!!
# 93   Prayers to all the dairy farmers in Abbotsford...
# 32   Also you need an oxygen meter reader. You coul...
# 49   maybe try finding an old fire nozzle  you coul...

# %% [markdown]
# ### Exploratory

# %%
# most number of likes
pd.set_option('display.max_colwidth', None)
df2.sort_values(by=['clean_comments'],ascending=False)
# Out:
#      Unnamed: 0  Unnamed: 0.1  \
# 14           14            14
# 114         114           114
# 98           98            98
# 96           96            96
# 19           19            19
# ..          ...           ...
# 143         143           143
# 27           27            27
# 78           78            78
# 168         168           168
# 175         175           175
#
#                                                                                                                Comments  \
# 14                                                                                               “PCV”, totally not PVC
# 114                                                                                                     yee ha shit day
# 98                                  will you not kill all the living manure bacteria spreading it while it's freezing ?
# 96                                                                                        will you be ice skating soon?
# 19    the main element  plants  & crop  get from manure is Nitrogen which is present in manure in the form of Ammonia #
# ..                                                                                                                  ...
# 143  2x20s uninteruptable advertisements in the beginning, do you have a hand in that?\n( last time, next time i quit )
# 27             2100 acres of land.  for 300 cows does it take that amount acre for feed for 300 cows?? love your videos
# 78          10ft deep and you are walking on quick sand without any safety gear. You have only one life. Use it wisely.
# 168                                                                                                        ...Cheers...
# 175                                                                                     👍👌🇨🇦❤, another Sask boy, me too
#
#                      Comment ID  Reply Count  \
# 14   UgzwI3gb4LE3_mwXRlB4AaABAg            0
# 114  UgwXVCZzQCJNv4h5uLl4AaABAg            1
# 98   UgxNzQ_-6OK_42Bgb-54AaABAg            1
# 96   UgxsDep_8W8h84Fhy_N4AaABAg            0
# 19   Ugw-ysYOY-tmJ_ITf594AaABAg            0
# ..                          ...          ...
# 143  Ugx-_2deo9m77IhnDRF4AaABAg            2
# 27   Ugyau3Cy9zWPhzBJqz14AaABAg            0
# 78   Ugyo5IEE60D9LQVg7Uh4AaABAg            0
# 168  UgwZyn8Pt2LWb3vKTXh4AaABAg            0
# 175  UgxnF7-sTb1T-0GG31d4AaABAg            0
#
#                                                                                                          clean_comments  \
# 14                                                                                               “PCV”, totally not PVC
# 114                                                                                                     yee ha shit day
# 98                                  will you not kill all the living manure bacteria spreading it while it's freezing ?
# 96                                                                                        will you be ice skating soon?
# 19    the main element  plants  & crop  get from manure is Nitrogen which is present in manure in the form of Ammonia #
# ..                                                                                                                  ...
# 143  2x20s uninteruptable advertisements in the beginning, do you have a hand in that?\n( last time, next time i quit )
# 27             2100 acres of land.  for 300 cows does it take that amount acre for feed for 300 cows?? love your videos
# 78          10ft deep and you are walking on quick sand without any safety gear. You have only one life. Use it wisely.
# 168                                                                                                        ...Cheers...
# 175                                                                                          , another Sask boy, me too
#
#                                                       SDK_sentiment  \
# 14            {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 114      {'neg': 0.45, 'neu': 0.25, 'pos': 0.3, 'compound': -0.296}
# 98   {'neg': 0.077, 'neu': 0.717, 'pos': 0.206, 'compound': 0.5168}
# 96            {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 19            {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ..                                                              ...
# 143    {'neg': 0.0, 'neu': 0.862, 'pos': 0.138, 'compound': 0.4939}
# 27     {'neg': 0.0, 'neu': 0.814, 'pos': 0.186, 'compound': 0.6767}
# 78     {'neg': 0.097, 'neu': 0.787, 'pos': 0.116, 'compound': 0.12}
# 168        {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4767}
# 175           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#      SDK_neg_sentiment  SDK_pos_sentiment  SDK_comp_sentiment
# 14               0.000              0.000              0.0000
# 114              0.450              0.300             -0.2960
# 98               0.077              0.206              0.5168
# 96               0.000              0.000              0.0000
# 19               0.000              0.000              0.0000
# ..                 ...                ...                 ...
# 143              0.000              0.138              0.4939
# 27               0.000              0.186              0.6767
# 78               0.097              0.116              0.1200
# 168              0.000              1.000              0.4767
# 175              0.000              0.000              0.0000
#
# [186 rows x 10 columns]

# %% [markdown]
# ### Build the Corpus

# %%
# !pip install scattertext
import spacy.cli
spacy.cli.download("en_core_web_lg")
import scattertext as st
# Out:
# Requirement already satisfied: scattertext in c:\python39\lib\site-packages (0.1.5)
# Requirement already satisfied: scipy in c:\python39\lib\site-packages (from scattertext) (1.7.1)
# Requirement already satisfied: flashtext in c:\python39\lib\site-packages (from scattertext) (2.7)
# Requirement already satisfied: pandas in c:\python39\lib\site-packages (from scattertext) (1.3.4)
# Requirement already satisfied: statsmodels in c:\python39\lib\site-packages (from scattertext) (0.13.0)
# Requirement already satisfied: gensim>=4.0.0 in c:\python39\lib\site-packages (from scattertext) (4.1.2)
# Requirement already satisfied: numpy in c:\python39\lib\site-packages (from scattertext) (1.21.2)
# Requirement already satisfied: scikit-learn in c:\python39\lib\site-packages (from scattertext) (1.0.2)
# Requirement already satisfied: mock in c:\python39\lib\site-packages (from scattertext) (4.0.3)
# Requirement already satisfied: six in c:\python39\lib\site-packages (from scattertext) (1.16.0)
# Requirement already satisfied: Cython==0.29.23 in c:\python39\lib\site-packages (from gensim>=4.0.0->scattertext) (0.29.23)
# Requirement already satisfied: smart-open>=1.8.1 in c:\python39\lib\site-packages (from gensim>=4.0.0->scattertext) (5.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\python39\lib\site-packages (from pandas->scattertext) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\python39\lib\site-packages (from pandas->scattertext) (2021.1)
# Requirement already satisfied: joblib>=0.11 in c:\python39\lib\site-packages (from scikit-learn->scattertext) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python39\lib\site-packages (from scikit-learn->scattertext) (3.0.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\python39\lib\site-packages (from statsmodels->scattertext) (0.5.2)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'c:\python39\python.exe -m pip install --upgrade pip' command.
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
nlp = spacy.load('en_core_web_lg')

# %%
df2.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                                                                                                                                                                                                                                                                    Comments  \
# 0                                                                     Farming, Fixing & Fabricating channel has some videos of them using skid steers under their barns scooping out the sand/solids and loading up large spreaders.  They have a nice operation and Andy has great videos.
# 1                                                                                                                                                                                                                                                                          It’s PVC not PCV
# 2                                                                                                                                                                                  To clean that pit at the barn you should rent a vacuum tank truck. It sucks the crap right out of there.
# 3  I went in here to comment and noticed Alex Drake's comment, which is I was going to comment on.  I read year after year about guys who die because of methane from sewers.  Please be careful.  Perhaps talk to your local fire department on safety precautions.  Love you guys videos.
# 4                                                                                 I would just make sure you carry a oxygen monitor when going in the pit. Very easy to get on Amazon. Abandoned mine explorers use them to detect lack of oxygen that could potentially cause you to pass.
#
#                    Comment ID  Reply Count  \
# 0  Ugzw-v1WGpnjr2-Xv2l4AaABAg            0
# 1  Ugz2TltI1vOdIWkhAml4AaABAg            0
# 2  Ugy03norOg4_escUAZl4AaABAg            0
# 3  Ugz18yAPJ-GiU9BboA54AaABAg            0
# 4  UgwyDGnrYQ3gqH5YIm94AaABAg            0
#
#                                                                                                                                                                                                                                                                              clean_comments  \
# 0                                                                     Farming, Fixing & Fabricating channel has some videos of them using skid steers under their barns scooping out the sand/solids and loading up large spreaders.  They have a nice operation and Andy has great videos.
# 1                                                                                                                                                                                                                                                                          It’s PVC not PCV
# 2                                                                                                                                                                                  To clean that pit at the barn you should rent a vacuum tank truck. It sucks the crap right out of there.
# 3  I went in here to comment and noticed Alex Drake's comment, which is I was going to comment on.  I read year after year about guys who die because of methane from sewers.  Please be careful.  Perhaps talk to your local fire department on safety precautions.  Love you guys videos.
# 4                                                                                 I would just make sure you carry a oxygen monitor when going in the pit. Very easy to get on Amazon. Abandoned mine explorers use them to detect lack of oxygen that could potentially cause you to pass.
#
#                                                     SDK_sentiment  \
# 0    {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.7845}
# 1           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 2    {'neg': 0.19, 'neu': 0.709, 'pos': 0.101, 'compound': -0.34}
# 3  {'neg': 0.103, 'neu': 0.719, 'pos': 0.178, 'compound': 0.5574}
# 4  {'neg': 0.117, 'neu': 0.725, 'pos': 0.158, 'compound': 0.2247}
#
#    SDK_neg_sentiment  SDK_pos_sentiment  SDK_comp_sentiment
# 0              0.000              0.173              0.7845
# 1              0.000              0.000              0.0000
# 2              0.190              0.101             -0.3400
# 3              0.103              0.178              0.5574
# 4              0.117              0.158              0.2247

# %%
corpus = st.CorpusFromPandas(df2, category_col='SDK_comp_sentiment', text_col= 'clean_comments', nlp=nlp).build()

# %% [markdown]
# ### Most defining words of the channel

# %%
print(list(corpus.get_scaled_f_scores_vs_background().index[:30]))
# Out:
# ['notifacation', 'pumpsystem', 'downand', 'purfort', 'problme', 'fead', 'uninteruptable', 'spanjer', 'manuer', 'kielstra', 'organik', 'hektar', 'smellovision', 'minure', 'shittiest', 'bcuz', 'wond', 'beelden', 'gasses', 'poopie', 'pcv', 'youtube', 'manure', 'altijd', 'instate', 'tilled', 'alleyways', 'slanting', 'wellies', 'delt']

# %%
import warnings
warnings.filterwarnings("ignore")
